# %% [markdown]
# # 1-1 category별로 여러 편의시설 설치된 곳을 찾기

# %%
import pandas as pd

# %%
import pdvega

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
from matplotlib import font_manager, rc
path = 'c:/windows/fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
test = pd.read_csv('table_dataclean.csv')

# %%
graph1 = test.groupby('category').facility_available_name.count()

# %%
graph1.vgplot.bar(width = 500, height=500,interactive=False)
# Out:
# <div class="vega-embed" id="9b8d07d9-8d54-48a7-ae50-eab38986b532"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %% [markdown]
# # category별로 편의시설 유형 파악

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
test.category.unique()
# Out:
# array(['subway', 'movie/concerthall', 'shopping/mart', 'publicparking',
#        'toilet/public', 'hospital', 'community service center',
#        'police station', 'post office', 'health center', 'bank', 'hotel',
#        'daycare center', 'education/job', 'elementary school',
#        'high school', 'junior high school', 'kindergarten', 'university',
#        'special-education school', 'library', 'beauty/hair', 'church',
#        'gym', 'training facility', 'park', 'welfare/senior', 'restaurant',
#        'exhibition center', 'welfare/etc', 'welfare/disabled',
#        'welfare/child', 'toilet/open', 'toilet/small'], dtype=object)

# %%
len(test.category.unique())
# Out:
# 34

# %%
test[test.category=='subway'].groupby('facility_available_name').facility_id.count()
# Out:
# facility_available_name
# 계단핸드레일      2
# 수평보행기       3
# 에스켈레이터    132
# 엘리베이터     211
# 화장실       213
# 휠체어리프트     77
# Name: facility_id, dtype: int64

# %%
graph2 = []
for result in test.category.unique():
    graph2.append(test[test.category ==  result].groupby('facility_available_name').facility_id.count())

# %%
for i, result in enumerate(test.category.unique()):
    print(result)
    graph2[i].vgplot.bar( width = 300, height=300,interactive = False)
# Out:
# subway
# <div class="vega-embed" id="78af17b9-61fb-4afd-b40b-d4a709a394fc"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# movie/concerthall
# <div class="vega-embed" id="e9fdaa1a-5bc7-4dd0-8b06-22ad2e6d6bb6"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# shopping/mart
# <div class="vega-embed" id="5da6287a-0911-4ea5-8e12-707c0d804f70"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# publicparking
# <div class="vega-embed" id="a4ed8ef3-f69f-42d0-8b4c-610629245a7c"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/public
# <div class="vega-embed" id="e5f17064-ce3f-4f5b-b807-23abb96314f3"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# hospital
# <div class="vega-embed" id="3d0270d2-f650-44a9-ac15-a42bb431c9e5"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# community service center
# <div class="vega-embed" id="2383ad85-214d-4c47-9092-fdf96e5fc752"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# police station
# <div class="vega-embed" id="5000696b-983b-4687-a154-2a49cabae555"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# post office
# <div class="vega-embed" id="414b7302-2a8e-4607-aa38-46ee0dff25b2"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# health center
# <div class="vega-embed" id="cb67439e-4da6-46e5-99d8-98e2394c07bf"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# bank
# <div class="vega-embed" id="e3a34be3-4e8a-40a7-b0c4-f3f1cf976ddf"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# hotel
# <div class="vega-embed" id="78495fcc-183d-41c0-998e-32e2346a9ed2"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# daycare center
# <div class="vega-embed" id="c23b41a8-54cd-4976-8636-16c79d4005ec"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# education/job
# <div class="vega-embed" id="9424bf1e-a509-4ac9-9ed8-07420cedd57c"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# elementary school
# <div class="vega-embed" id="f618b8b8-9cb6-4cc4-a4d8-e89091c201a7"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# high school
# <div class="vega-embed" id="96ee4be0-eb2e-4f57-89ac-73fda191e14f"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# junior high school
# <div class="vega-embed" id="0d77786d-6733-4ace-ad0b-b7d34be1cf22"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# kindergarten
# <div class="vega-embed" id="6aa7f87b-faf4-4dc4-bc3c-2cc1894ca10b"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# university
# <div class="vega-embed" id="ee72f999-2714-480e-ae50-340d7bc8284d"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# special-education school
# <div class="vega-embed" id="32f12f4b-34ca-45d9-bb34-0ab3b1819a51"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# library
# <div class="vega-embed" id="5e183da3-661f-47ab-838d-1604d7d9f517"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# beauty/hair
# <div class="vega-embed" id="08e02911-4e8b-4215-984c-c2cae47767f4"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# church
# <div class="vega-embed" id="92f3833a-b76e-48a7-abea-cd78ef4d1b21"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# gym
# <div class="vega-embed" id="6d26ab32-60d1-4f43-aade-db1dff91df7e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# training facility
# <div class="vega-embed" id="a9e95b23-9fe2-4d49-9ea3-d61c7a908439"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# park
# <div class="vega-embed" id="b2ecdfbd-a2bb-471a-b847-2993c2560ffa"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/senior
# <div class="vega-embed" id="1bbf0c99-16fd-4e8a-b807-12a9c18edfb1"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# restaurant
# <div class="vega-embed" id="5987cdd0-4cdd-446c-8fce-4cf919b06562"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# exhibition center
# <div class="vega-embed" id="e3efa014-f023-4c7c-8fa2-41a4c5c3d580"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/etc
# <div class="vega-embed" id="5742d671-ab32-40c0-aa52-d0996c8627e9"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/disabled
# <div class="vega-embed" id="36acc382-af84-40f1-b003-4efc63839aaf"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/child
# <div class="vega-embed" id="e0b2c2cb-e9c9-48d3-bc64-073d9e4baf6b"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/open
# <div class="vega-embed" id="6a228992-a452-41d5-86d2-64d0ef8fee32"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/small
# <div class="vega-embed" id="aa0bf11a-369c-4e1d-922f-5432fc6d63b1"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46517 entries, 0 to 46516
# Data columns (total 10 columns):
# Unnamed: 0                 46517 non-null int64
# category                   46517 non-null object
# lat                        46517 non-null float64
# lon                        46517 non-null float64
# place_address              45879 non-null object
# place_id                   46517 non-null int64
# place_name                 46517 non-null object
# facility_available_name    46517 non-null object
# facility_is_available      15024 non-null object
# facility_id                46517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
test.place_address.isna().sum()
# Out:
# 638

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46517 entries, 0 to 46516
# Data columns (total 10 columns):
# Unnamed: 0                 46517 non-null int64
# category                   46517 non-null object
# lat                        46517 non-null float64
# lon                        46517 non-null float64
# place_address              45879 non-null object
# place_id                   46517 non-null int64
# place_name                 46517 non-null object
# facility_available_name    46517 non-null object
# facility_is_available      15024 non-null object
# facility_id                46517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
ttest = test.copy()

# %%
ttest.place_address.isna().sum()
# Out:
# 638

# %%
ttest.place_id.isna().sum()
# Out:
# 0

# %%
ttest.isna().any()
# Out:
# Unnamed: 0                 False
# category                   False
# lat                        False
# lon                        False
# place_address               True
# place_id                   False
# place_name                 False
# facility_available_name    False
# facility_is_available       True
# facility_id                False
# dtype: bool

# %%
ttest.isna().sum()
# Out:
# Unnamed: 0                     0
# category                       0
# lat                            0
# lon                            0
# place_address                638
# place_id                       0
# place_name                     0
# facility_available_name        0
# facility_is_available      31493
# facility_id                    0
# dtype: int64

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46517 entries, 0 to 46516
# Data columns (total 10 columns):
# Unnamed: 0                 46517 non-null int64
# category                   46517 non-null object
# lat                        46517 non-null float64
# lon                        46517 non-null float64
# place_address              45879 non-null object
# place_id                   46517 non-null int64
# place_name                 46517 non-null object
# facility_available_name    46517 non-null object
# facility_is_available      15024 non-null object
# facility_id                46517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
import numpy as np

# %%
ttest[ttest.place_address.isna()].category.count()
# Out:
# 638

# %%
ttest.dropna(inplace=True,subset={'place_address'})

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45879 entries, 638 to 46516
# Data columns (total 10 columns):
# Unnamed: 0                 45879 non-null int64
# category                   45879 non-null object
# lat                        45879 non-null float64
# lon                        45879 non-null float64
# place_address              45879 non-null object
# place_id                   45879 non-null int64
# place_name                 45879 non-null object
# facility_available_name    45879 non-null object
# facility_is_available      14386 non-null object
# facility_id                45879 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.9+ MB

# %%
ttest.isna().sum()
# Out:
# Unnamed: 0                     0
# category                       0
# lat                            0
# lon                            0
# place_address                  0
# place_id                       0
# place_name                     0
# facility_available_name        0
# facility_is_available      31493
# facility_id                    0
# dtype: int64

# %%
## 어드레스없는거는 모드 드롭함.

# %%
ttest.head()
# Out:
#      Unnamed: 0           category        lat         lon  \
# 638         638  movie/concerthall  37.583269  127.002443
# 639         639  movie/concerthall  37.583269  127.002443
# 640         640  movie/concerthall  37.523930  127.025143
# 641         641  movie/concerthall  37.523930  127.025143
# 642         642  movie/concerthall  37.523930  127.025143
#
#             place_address  place_id     place_name facility_available_name  \
# 638    서울특별시 종로구 동숭동 1-37     10000  A아트홀(구.신연아트홀)                주출입구 접근로
# 639    서울특별시 종로구 동숭동 1-37     10000  A아트홀(구.신연아트홀)            주출입구 높이차이 제거
# 640  서울특별시 강남구 신사동  568-2     10001         BBC씨어터                주출입구 접근로
# 641  서울특별시 강남구 신사동  568-2     10001         BBC씨어터             장애인 전용 주차구역
# 642  서울특별시 강남구 신사동  568-2     10001         BBC씨어터            주출입구 높이차이 제거
#
#     facility_is_available  facility_id
# 638                  이용불편       100000
# 639                  이용가능       100001
# 640                  이용가능       100002
# 641                  이용가능       100003
# 642                  이용가능       100004

# %%
ttest.place_address.str.contains('구').sum()
# Out:
# 45859

# %%
ttest.iloc[45005]
# Out:
# Unnamed: 0                                45643
# category                            toilet/open
# lat                                     37.5329
# lon                                     127.145
# place_address                      서울특별시 둔촌동 산6
# place_id                                  30872
# place_name                 일자산자연공원(둔촌약수터입구) 화장실
# facility_available_name                 여성용-대변기
# facility_is_available                       NaN
# facility_id                              303305
# Gu
# Name: 45643, dtype: object

# %%
ttest.loc[45005, ['place_address'] ] = '서울특별시 강동구 둔촌동 산6'

# %%
ttest.loc[45005, ['place_address'] ]
# Out:
# place_address    서울특별시 강동구 둔촌동 산6
# Name: 45005, dtype: object

# %%
# ttest.iloc[45005]['place_address'] = '서울특별시 강동구 둔촌동 산6'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ttest.loc[45005, ['place_address'] ]
# Out:
# place_address    서울특별시 강동구 둔촌동 산6
# Name: 45005, dtype: object

# %%
for i,v in enumerate(ttest.place_address.str.split(' ')):
    if not v[1].endswith('구'):
        print(i,v)
# Out:
# 45005 ['서울특별시', '둔촌동', '산6']
# 45006 ['서울특별시', '둔촌동', '산6']
# 45007 ['서울특별시', '둔촌동', '산6']
# 45008 ['서울특별시', '둔촌동', '산6']
# 45009 ['서울특별시', '둔촌동', '산94']
# 45010 ['서울특별시', '둔촌동', '산94']
# 45011 ['서울특별시', '둔촌동', '산94']
# 45205 ['서울특별시', '강일동', '675-3']
# 45206 ['서울특별시', '강일동', '675-3']
# 45207 ['서울특별시', '강일동', '675-3']
# 45208 ['서울특별시', '강일동', '675-3']
# 45209 ['서울특별시', '강일동', '675-3']
# 45210 ['서울특별시', '강일동', '675-3']
# 45211 ['서울특별시', '강일동', '675-3']
# 45212 ['서울특별시', '강일동', '675-3']
# 45213 ['서울특별시', '강일동', '675-7']
# 45214 ['서울특별시', '강일동', '675-7']
# 45215 ['서울특별시', '강일동', '675-7']
# 45216 ['서울특별시', '강일동', '675-7']
# 45217 ['서울특별시', '강일동', '675-7']

# %%
ttest['Gu']=''

# %%
ttest[ttest.place_address.str.contains('구')==False]['Gu']='강동구'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ttest.head()
# Out:
#      Unnamed: 0           category        lat         lon  \
# 638         638  movie/concerthall  37.583269  127.002443
# 639         639  movie/concerthall  37.583269  127.002443
# 640         640  movie/concerthall  37.523930  127.025143
# 641         641  movie/concerthall  37.523930  127.025143
# 642         642  movie/concerthall  37.523930  127.025143
#
#             place_address  place_id     place_name facility_available_name  \
# 638    서울특별시 종로구 동숭동 1-37     10000  A아트홀(구.신연아트홀)                주출입구 접근로
# 639    서울특별시 종로구 동숭동 1-37     10000  A아트홀(구.신연아트홀)            주출입구 높이차이 제거
# 640  서울특별시 강남구 신사동  568-2     10001         BBC씨어터                주출입구 접근로
# 641  서울특별시 강남구 신사동  568-2     10001         BBC씨어터             장애인 전용 주차구역
# 642  서울특별시 강남구 신사동  568-2     10001         BBC씨어터            주출입구 높이차이 제거
#
#     facility_is_available  facility_id
# 638                  이용불편       100000
# 639                  이용가능       100001
# 640                  이용가능       100002
# 641                  이용가능       100003
# 642                  이용가능       100004

# %%
ff.place_address.str.split(' ').head()
# Out:
# 638       [서울특별시, 종로구, 동숭동, 1-37]
# 639       [서울특별시, 종로구, 동숭동, 1-37]
# 640    [서울특별시, 강남구, 신사동, , 568-2]
# 641    [서울특별시, 강남구, 신사동, , 568-2]
# 642    [서울특별시, 강남구, 신사동, , 568-2]
# Name: place_address, dtype: object

# %%
for i,v in enumerate(ff.place_address.str.split(' ')):
    if not v[1].endswith('구'):
        print(v)
# Out:
# ['서울특별시', '둔촌동', '산6']
# ['서울특별시', '둔촌동', '산6']
# ['서울특별시', '둔촌동', '산6']
# ['서울특별시', '둔촌동', '산6']
# ['서울특별시', '둔촌동', '산94']
# ['서울특별시', '둔촌동', '산94']
# ['서울특별시', '둔촌동', '산94']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-3']
# ['서울특별시', '강일동', '675-7']
# ['서울특별시', '강일동', '675-7']
# ['서울특별시', '강일동', '675-7']
# ['서울특별시', '강일동', '675-7']
# ['서울특별시', '강일동', '675-7']

# %%
# 결국 강동구가 문제였음.
# 없는놈들은 구에 강동구를 넣기로함.

# %%
ff.iloc[54403:54415]
# Out:
#          place_address
# 60182  서울특별시 강일동 675-3
# 60183  서울특별시 강일동 675-3
# 60184  서울특별시 강일동 675-3
# 60185  서울특별시 강일동 675-3
# 60186  서울특별시 강일동 675-3
# 60187  서울특별시 강일동 675-3
# 60188  서울특별시 강일동 675-3
# 60189  서울특별시 강일동 675-3
# 60190  서울특별시 강일동 675-7
# 60191  서울특별시 강일동 675-7
# 60192  서울특별시 강일동 675-7
# 60193  서울특별시 강일동 675-7

# %%
ttest[ttest['place_id'].isna()==True]
# Out:
#        Unnamed: 0  index category  lat  lon place_address  place_id  \
# 16176       16176    NaN      NaN  NaN  NaN           NaN       NaN
# 16177       16177    NaN      NaN  NaN  NaN           NaN       NaN
# 16178       16178    NaN      NaN  NaN  NaN           NaN       NaN
# 16179       16179    NaN      NaN  NaN  NaN           NaN       NaN
# 16180       16180    NaN      NaN  NaN  NaN           NaN       NaN
# 16181       16181    NaN      NaN  NaN  NaN           NaN       NaN
# 16182       16182    NaN      NaN  NaN  NaN           NaN       NaN
# 16183       16183    NaN      NaN  NaN  NaN           NaN       NaN
# 16184       16184    NaN      NaN  NaN  NaN           NaN       NaN
# 16185       16185    NaN      NaN  NaN  NaN           NaN       NaN
# 16186       16186    NaN      NaN  NaN  NaN           NaN       NaN
# 16187       16187    NaN      NaN  NaN  NaN           NaN       NaN
# 16188       16188    NaN      NaN  NaN  NaN           NaN       NaN
# 16189       16189    NaN      NaN  NaN  NaN           NaN       NaN
# 16190       16190    NaN      NaN  NaN  NaN           NaN       NaN
# 16191       16191    NaN      NaN  NaN  NaN           NaN       NaN
# 16195       16195    NaN      NaN  NaN  NaN           NaN       NaN
# 16196       16196    NaN      NaN  NaN  NaN           NaN       NaN
# 16197       16197    NaN      NaN  NaN  NaN           NaN       NaN
# 16198       16198    NaN      NaN  NaN  NaN           NaN       NaN
# 16199       16199    NaN      NaN  NaN  NaN           NaN       NaN
# 16200       16200    NaN      NaN  NaN  NaN           NaN       NaN
# 16201       16201    NaN      NaN  NaN  NaN           NaN       NaN
# 16210       16210    NaN      NaN  NaN  NaN           NaN       NaN
# 16211       16211    NaN      NaN  NaN  NaN           NaN       NaN
# 16212       16212    NaN      NaN  NaN  NaN           NaN       NaN
# 16213       16213    NaN      NaN  NaN  NaN           NaN       NaN
# 16214       16214    NaN      NaN  NaN  NaN           NaN       NaN
# 16215       16215    NaN      NaN  NaN  NaN           NaN       NaN
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
ttest.place_address = ff

# %%
ttest.head()
# Out:
#    Unnamed: 0  index category        lat         lon place_address  place_id  \
# 0           0    0.0   subway  37.492317  127.118104           NaN       0.0
# 1           1    1.0   subway  37.492317  127.118104           NaN       0.0
# 2           2    2.0   subway  37.492317  127.118104           NaN       0.0
# 3           3    3.0   subway  37.480890  126.882574           NaN       1.0
# 4           4    4.0   subway  37.480890  126.882574           NaN       1.0
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능     900000.0
# 1       가락시장                   엘리베이터                  이용가능     900001.0
# 2       가락시장                  휠체어리프트                  이용가능     900002.0
# 3    가산디지털단지                  에스켈레이터                  이용가능     900003.0
# 4    가산디지털단지                     화장실                  이용가능     900004.0

# %%
ttest.place_address.dropna(inplace=True)

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
ttest.place_address.isna().sum()
# Out:
# 0

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=graph2[0])

p = figure( plot_height=350, toolbar_location=None, title="Fruit Counts")
# p.vbar(x='fruits', top='counts', width=0.9, source=graph2[0], legend="fruits",
#        line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7c5c79f479dd> in <module>()
#      10 counts = [5, 3, 4, 2, 4, 6]
#      11
# ---> 12 source = ColumnDataSource(data=graph2[0])
#      13
#      14 p = figure( plot_height=350, toolbar_location=None, title="Fruit Counts")
#
# ~\Anaconda3\lib\site-packages\bokeh\models\sources.py in __init__(self, *args, **kw)
#     127                 raw_data = self._data_from_groupby(raw_data)
#     128             else:
# --> 129                 raise ValueError("expected a dict or pandas.DataFrame, got %s" % raw_data)
#     130         super(ColumnDataSource, self).__init__(**kw)
#     131         self.data.update(raw_data)
#
# ValueError: expected a dict or pandas.DataFrame, got facility_available_name
# 계단핸드레일      2
# 수평보행기       3
# 에스켈레이터    132
# 엘리베이터     211
# 화장실       213
# 휠체어리프트     77
# Name: facility_id, dtype: int64

# %%
source
# Out:
# ColumnDataSource(id='4410a533-4c00-4eed-9031-260f144e095f', ...)
