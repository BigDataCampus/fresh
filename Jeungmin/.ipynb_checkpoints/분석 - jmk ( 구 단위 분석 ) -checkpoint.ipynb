# %% [markdown]
# # 1-1 category별로 여러 편의시설 설치된 곳을 찾기

# %%
import pandas as pd

# %%
import pdvega

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
from matplotlib import font_manager, rc
path = 'c:/windows/fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
test = pd.read_csv('../table_dataclean.csv')

# %%
graph1 = test.groupby('category').facility_available_name.count()

# %%
graph1.vgplot.bar(width = 500, height=500,interactive=False)
# Out:
# <div class="vega-embed" id="82736663-b405-4234-973f-5abcf7ea6797"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %% [markdown]
# # category별로 편의시설 유형 파악

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
test.category.unique()
# Out:
# array(['subway', 'movie/concerthall', 'shopping/mart', 'publicparking',
#        'toilet/public', 'hospital', 'community service center',
#        'police station', 'post office', 'health center', 'bank', 'hotel',
#        'daycare center', 'education/job', 'elementary school',
#        'high school', 'junior high school', 'kindergarten', 'university',
#        'special-education school', 'library', 'beauty/hair', 'church',
#        'gym', 'training facility', 'park', 'welfare/senior', 'restaurant',
#        'exhibition center', 'welfare/etc', 'welfare/disabled',
#        'welfare/child', 'toilet/open', 'toilet/small'], dtype=object)

# %%
len(test.category.unique())
# Out:
# 34

# %%
test[test.category=='subway'].groupby('facility_available_name').facility_id.count()
# Out:
# facility_available_name
# 계단핸드레일      2
# 수평보행기       3
# 에스켈레이터    134
# 엘리베이터     213
# 화장실       215
# 휠체어리프트     79
# Name: facility_id, dtype: int64

# %%
graph2 = []
for result in test.category.unique():
    graph2.append(test[test.category ==  result].groupby('facility_available_name').facility_id.count())

# %%
for i, result in enumerate(test.category.unique()):
    print(result)
    graph2[i].vgplot.bar( width = 300, height=300,interactive = False)
# Out:
# subway
# movie/concerthall
# shopping/mart
# publicparking
# toilet/public
# hospital
# community service center
# police station
# post office
# health center
# bank
# hotel
# daycare center
# education/job
# elementary school
# high school
# junior high school
# kindergarten
# university
# special-education school
# library
# beauty/hair
# church
# gym
# training facility
# park
# welfare/senior
# restaurant
# exhibition center
# welfare/etc
# welfare/disabled
# welfare/child
# toilet/open
# toilet/small

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46525 entries, 0 to 46524
# Data columns (total 10 columns):
# Unnamed: 0                 46525 non-null int64
# category                   46525 non-null object
# lat                        46525 non-null float64
# lon                        46525 non-null float64
# place_address              46525 non-null object
# place_id                   46525 non-null int64
# place_name                 46525 non-null object
# facility_available_name    46525 non-null object
# facility_is_available      15032 non-null object
# facility_id                46525 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
test.place_address.isna().sum()
# Out:
# 0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46525 entries, 0 to 46524
# Data columns (total 10 columns):
# Unnamed: 0                 46525 non-null int64
# category                   46525 non-null object
# lat                        46525 non-null float64
# lon                        46525 non-null float64
# place_address              46525 non-null object
# place_id                   46525 non-null int64
# place_name                 46525 non-null object
# facility_available_name    46525 non-null object
# facility_is_available      15032 non-null object
# facility_id                46525 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
ttest = test.copy()

# %%
ttest.place_address.isna().sum()
# Out:
# 0

# %%
ttest.place_id.isna().sum()
# Out:
# 0

# %%
ttest.isna().any()
# Out:
# Unnamed: 0                 False
# category                   False
# lat                        False
# lon                        False
# place_address              False
# place_id                   False
# place_name                 False
# facility_available_name    False
# facility_is_available       True
# facility_id                False
# dtype: bool

# %%
ttest.isna().sum()
# Out:
# Unnamed: 0                     0
# category                       0
# lat                            0
# lon                            0
# place_address                  0
# place_id                       0
# place_name                     0
# facility_available_name        0
# facility_is_available      31493
# facility_id                    0
# dtype: int64

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46525 entries, 0 to 46524
# Data columns (total 10 columns):
# Unnamed: 0                 46525 non-null int64
# category                   46525 non-null object
# lat                        46525 non-null float64
# lon                        46525 non-null float64
# place_address              46525 non-null object
# place_id                   46525 non-null int64
# place_name                 46525 non-null object
# facility_available_name    46525 non-null object
# facility_is_available      15032 non-null object
# facility_id                46525 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
import numpy as np

# %%
ttest[ttest.place_address.isna()].category.count()
# Out:
# 0

# %%
# ttest.dropna(inplace=True,subset={'place_address'})

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46525 entries, 0 to 46524
# Data columns (total 10 columns):
# Unnamed: 0                 46525 non-null int64
# category                   46525 non-null object
# lat                        46525 non-null float64
# lon                        46525 non-null float64
# place_address              46525 non-null object
# place_id                   46525 non-null int64
# place_name                 46525 non-null object
# facility_available_name    46525 non-null object
# facility_is_available      15032 non-null object
# facility_id                46525 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
ttest.isna().sum()
# Out:
# Unnamed: 0                     0
# category                       0
# lat                            0
# lon                            0
# place_address                  0
# place_id                       0
# place_name                     0
# facility_available_name        0
# facility_is_available      31493
# facility_id                    0
# dtype: int64

# %%
## 어드레스없는거는 모드 드롭함.

# %%
ttest.head()
# Out:
#    Unnamed: 0 category        lat         lon place_address  place_id  \
# 0           0   subway  37.492317  127.118104     서울특별시 송파구         0
# 1           1   subway  37.492317  127.118104     서울특별시 송파구         0
# 2           2   subway  37.492317  127.118104     서울특별시 송파구         0
# 3           3   subway  37.480890  126.882574     서울특별시 금천구         1
# 4           4   subway  37.480890  126.882574     서울특별시 금천구         1
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능       900000
# 1       가락시장                   엘리베이터                  이용가능       900001
# 2       가락시장                  휠체어리프트                  이용가능       900002
# 3    가산디지털단지                  에스켈레이터                  이용가능       900003
# 4    가산디지털단지                     화장실                  이용가능       900004

# %%
ttest.place_address.str.contains('구 ').sum()
# Out:
# 45879

# %%
for i,v in enumerate(ttest.place_address.str.split(' ')):
    if not v[1].endswith('구'):
        print(i,v)
# Out:
# 46 ['서울특별시', 'null']
# 47 ['서울특별시', 'null']
# 48 ['서울특별시', 'null']
# 402 ['서울특별시', 'null']
# 403 ['서울특별시', 'null']
# 525 ['서울특별시', 'null']
# 526 ['서울특별시', 'null']
# 575 ['서울특별시', 'null']
# 576 ['서울특별시', 'null']
# 577 ['서울특별시', 'null']

# %%
ttest.head()
# Out:
#    Unnamed: 0 category        lat         lon place_address  place_id  \
# 0           0   subway  37.492317  127.118104     서울특별시 송파구         0
# 1           1   subway  37.492317  127.118104     서울특별시 송파구         0
# 2           2   subway  37.492317  127.118104     서울특별시 송파구         0
# 3           3   subway  37.480890  126.882574     서울특별시 금천구         1
# 4           4   subway  37.480890  126.882574     서울특별시 금천구         1
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능       900000
# 1       가락시장                   엘리베이터                  이용가능       900001
# 2       가락시장                  휠체어리프트                  이용가능       900002
# 3    가산디지털단지                  에스켈레이터                  이용가능       900003
# 4    가산디지털단지                     화장실                  이용가능       900004

# %%
ttest.place_address.str.split(' ')
# Out:
# 0                     [서울특별시, 송파구]
# 1                     [서울특별시, 송파구]
# 2                     [서울특별시, 송파구]
# 3                     [서울특별시, 금천구]
# 4                     [서울특별시, 금천구]
# 5                     [서울특별시, 금천구]
# 6                     [서울특별시, 금천구]
# 7                     [서울특별시, 강남구]
# 8                     [서울특별시, 강남구]
# 9                     [서울특별시, 강남구]
# 10                    [서울특별시, 강동구]
# 11                    [서울특별시, 강동구]
# 12                    [서울특별시, 강동구]
# 13                    [서울특별시, 강동구]
# 14                    [서울특별시, 광진구]
# 15                    [서울특별시, 광진구]
# 16                    [서울특별시, 광진구]
# 17                    [서울특별시, 광진구]
# 18                    [서울특별시, 광진구]
# 19                    [서울특별시, 강서구]
# 20                    [서울특별시, 강서구]
# 21                    [서울특별시, 송파구]
# 22                    [서울특별시, 송파구]
# 23                    [서울특별시, 송파구]
# 24                    [서울특별시, 송파구]
# 25                    [서울특별시, 광진구]
# 26                    [서울특별시, 광진구]
# 27                    [서울특별시, 광진구]
# 28                    [서울특별시, 광진구]
# 29                    [서울특별시, 강동구]
#                    ...
# 46495     [서울특별시, 서초구, 방배동, 산75-4]
# 46496     [서울특별시, 서초구, 방배동, 산75-4]
# 46497     [서울특별시, 서초구, 반포동, 115-4]
# 46498     [서울특별시, 서초구, 반포동, 115-4]
# 46499     [서울특별시, 서초구, 반포동, 115-4]
# 46500     [서울특별시, 서초구, 반포동, 115-4]
# 46501     [서울특별시, 서초구, 반포동, 115-4]
# 46502       [서울특별시, 서초구, 방배동, 599]
# 46503       [서울특별시, 서초구, 방배동, 599]
# 46504       [서울특별시, 서초구, 방배동, 599]
# 46505     [서울특별시, 서초구, 양재동, 126-1]
# 46506     [서울특별시, 서초구, 양재동, 126-1]
# 46507     [서울특별시, 서초구, 양재동, 126-1]
# 46508    [서울특별시, 서초구, 양재동, 261-23]
# 46509    [서울특별시, 서초구, 양재동, 261-23]
# 46510    [서울특별시, 서초구, 양재동, 261-23]
# 46511    [서울특별시, 서초구, 양재동, 261-23]
# 46512    [서울특별시, 서초구, 양재동, 261-23]
# 46513     [서울특별시, 서초구, 우면동, 143-6]
# 46514     [서울특별시, 서초구, 우면동, 143-6]
# 46515     [서울특별시, 서초구, 우면동, 143-6]
# 46516     [서울특별시, 서초구, 우면동, 143-6]
# 46517     [서울특별시, 서초구, 우면동, 143-6]
# 46518    [서울특별시, 성동구, 사근동, 102-28]
# 46519    [서울특별시, 성동구, 사근동, 102-28]
# 46520    [서울특별시, 성동구, 사근동, 102-28]
# 46521    [서울특별시, 성동구, 사근동, 102-28]
# 46522       [서울특별시, 성동구, 마장동, 811]
# 46523       [서울특별시, 성동구, 마장동, 811]
# 46524       [서울특별시, 성동구, 마장동, 811]
# Name: place_address, Length: 46525, dtype: object

# %%
gu_list = []

# %%
for i,v in enumerate(ttest.place_address.str.split(' ')):
    gu_list.append(v[1])

# %%
len(gu_list)
# Out:
# 46525

# %%
gu_list[0]
# Out:
# '송파구'

# %%
se= pd.Series(gu_list)

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46525 entries, 0 to 46524
# Data columns (total 10 columns):
# Unnamed: 0                 46525 non-null int64
# category                   46525 non-null object
# lat                        46525 non-null float64
# lon                        46525 non-null float64
# place_address              46525 non-null object
# place_id                   46525 non-null int64
# place_name                 46525 non-null object
# facility_available_name    46525 non-null object
# facility_is_available      15032 non-null object
# facility_id                46525 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
len(se.values)
# Out:
# 46525

# %%
ttest['Gu'] = se.values

# %%
ttest.head()
# Out:
#    Unnamed: 0 category        lat         lon place_address  place_id  \
# 0           0   subway  37.492317  127.118104     서울특별시 송파구         0
# 1           1   subway  37.492317  127.118104     서울특별시 송파구         0
# 2           2   subway  37.492317  127.118104     서울특별시 송파구         0
# 3           3   subway  37.480890  126.882574     서울특별시 금천구         1
# 4           4   subway  37.480890  126.882574     서울특별시 금천구         1
#
#   place_name facility_available_name facility_is_available  facility_id   Gu
# 0       가락시장                     화장실                  이용가능       900000  송파구
# 1       가락시장                   엘리베이터                  이용가능       900001  송파구
# 2       가락시장                  휠체어리프트                  이용가능       900002  송파구
# 3    가산디지털단지                  에스켈레이터                  이용가능       900003  금천구
# 4    가산디지털단지                     화장실                  이용가능       900004  금천구

# %%
graph1 = ttest.groupby('Gu').facility_available_name.count()

# %%
graph1.vgplot.bar(width = 500, height=500,interactive=False)
# Out:
# <div class="vega-embed" id="aef033d8-350d-40c1-81d4-fc912bf590ef"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
graph2.vgplot.bar(width = 500, height=500,interactive=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-e6ac729bc2a0> in <module>()
# ----> 1 graph2.vgplot.bar(width = 500, height=500,interactive=False)
#
# AttributeError: 'list' object has no attribute 'vgplot'

# %%
ttest.to_csv('clean_table_with_gu.csv')

# %%
ttest.head()
# Out:
#    Unnamed: 0 category        lat         lon place_address  place_id  \
# 0           0   subway  37.492317  127.118104     서울특별시 송파구         0
# 1           1   subway  37.492317  127.118104     서울특별시 송파구         0
# 2           2   subway  37.492317  127.118104     서울특별시 송파구         0
# 3           3   subway  37.480890  126.882574     서울특별시 금천구         1
# 4           4   subway  37.480890  126.882574     서울특별시 금천구         1
#
#   place_name facility_available_name facility_is_available  facility_id   Gu
# 0       가락시장                     화장실                  이용가능       900000  송파구
# 1       가락시장                   엘리베이터                  이용가능       900001  송파구
# 2       가락시장                  휠체어리프트                  이용가능       900002  송파구
# 3    가산디지털단지                  에스켈레이터                  이용가능       900003  금천구
# 4    가산디지털단지                     화장실                  이용가능       900004  금천구

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=graph2[0])

p = figure( plot_height=350, toolbar_location=None, title="Fruit Counts")
# p.vbar(x='fruits', top='counts', width=0.9, source=graph2[0], legend="fruits",
#        line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)

# %%
source
