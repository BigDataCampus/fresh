# %%
import requests
from bs4 import BeautifulSoup
import re
import sys
from time import sleep

# %%
headers = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
}

parms = {
    "pagenum" : 1,
    "Depth" : 3111
}

# %%
url = "http://disability.seoul.go.kr/amenity/sightSeeingConven/sightSeeingConven.jsp"

# %%
def getUrl(url, parameter=None, num_retries=2, select=None):
    html = requests.get(url, params=parameter, headers=headers)
    
    if 500 <= html.status_code  < 600 and num_retries > 0:
        print(html.status_code, html.reason)
        return getUrl(url, params, num_retries=1)
        
    dom = BeautifulSoup(html.text, "lxml")
    links = dom.select(select)
    
    return links

# %%
select_css = { 'place': 'ul.travel-list2 > li > dl > dt > a ',
               'address' : 'ul.travel-list2 > li > dl > dd > p',
               'phone' : '.tel',
               'facility': 'ul.travel-list2 > li > dl > dd > ul.facil' }

# %%
place_Depth_code = {
    "korean" : 3111,
    "western" : 3211,
    "chinese"  : 3311,
    "japanese" : 3411,
    "flour_based" : 3511,
    "other" : 3611,
}

# 1. 한식 2. 양식 3. 중식 4. 일식 5. 분식 6. 기타

# %%
korean = []
western = []
chinese = []
japanese = []
flour_based = []
other = []

# %%
# 1. 한식 2. 양식 3. 중식 4. 일식 5. 분식 6. 기타  
# type 구조 [{ }] 리스안에 딕셔너리 구조 
final_dict = {
'korean' : None ,
'western' : None ,
'chinese' : None ,
'japanese' : None ,
'flour_based' : None ,
'other' : None,

}

# %%
for place in place_Depth_code:
    place_code = place_Depth_code[place]
    parms['Depth'] = place_code
    result = []  
    while True:
        for select in select_css:
            get_info = getUrl(url, parameter = parms, select = select_css[select])
            # 장소, 장소_사이트, 주소, 전화번호, 편의시설
            if 'place' is select:
                place_name = [info.text for info in get_info] # 장소
                place_href = [info['href'] for info in get_info] # 장소_사이트
            if 'address' is select:
                address_pre = [re.sub(u'\xa0 \r\n\t*',"",info.text) for info in get_info] # 주소
                address =[re.sub(u'주소 :  ',"",info) for info in address_pre]
#             if 'phone' is select:
#                 phone = [info.text for info in get_info] # 전화번호
#             if 'facility' is select:
#                 facility_pre_select = [info for info in get_info] # 편의시설
                
        if get_info: 
            for info_num in range(0, len(place_name)):
#                 facility_select =  facility_pre_select[info_num].select('li > img')
#                 facility_select = [row_facility['alt'] for row_facility in facility_select]
#                 print(facility_select)
                info_dict = {'place_name' : place_name[info_num],
                             'place_href' : 'http://disability.seoul.go.kr'+place_href[info_num],
                             'place_address' : address[info_num],
#                              'place_facility' : facility_select
                             }  #     #
                result.append(info_dict)
            print(info_dict)
            parms['pagenum'] = parms['pagenum'] + 1
            # pagenum ->for next page
        else:
            parms['pagenum'] = 1
            break
    final_dict[place] = result

# %%
number_len =0 
for place in place_Depth_code:
    number_len += len(final_dict[place])
print(number_len)
# Out:
# 414

# %%
facility_select =  "div.imgIcoBview" # 필요한 부분만 자르기

# %%
facility_available_name_select = "dt > a" # 시설물 설치된 이름
facility_is_available_select = "dt > span" # 시설물 이용가능 or 이용 불편 
facility_info_select = "ul.bulListDot > li" # 시설물 상세 정보 
# place_name  = "div.viewTitle p.sisulTitle" # 시설물 상세 정보

# %%
final_dicts = {}
info_result = [] 
for place in place_Depth_code:

    for i, info in enumerate(final_dict[place]):
        info_result = [] 
        get_info = getUrl(info['place_href'], select = facility_select)
        facility_available_name= [info.text for info in get_info[0].select(facility_available_name_select)]
        facility_is_available = [info.text for info in get_info[0].select(facility_is_available_select)]
        facility_info = [info for info in get_info[0].select(facility_info_select)]
        facility_info = [info.__str__() for info in facility_info]
        facility_info = [ re.sub('^<li>|-|(<br/>)?</li>$' , '' , info).split('<br/>') for info in facility_info]
        
        for info_num in range(0, len(facility_available_name)):
            info_dict  = {'facility_available_name' : facility_available_name[info_num],
                     'facility_is_available' : facility_is_available[info_num],
                     'facility_info' : facility_info[info_num]
                     }
            info_result.append(info_dict)
        a = str(i)
        final_dict[place][i]['facility_detail_info'] = info_result
        info_result = None 
# print( final_dict[place][i]['facility_detail_info'])
#         print( final_dict[place][i]['facility_detail_info'])
#         print(final_dict[place][i]['facility_detail_info'])

# %%
import json
import urllib.request
import urllib.request
import datetime
import time
import json

# %%
def get_request_url(url):
    
    client_id="R63uNWNQiaTp1EeZl7bW"
    client_secret = "1Im1JohssC"
    
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None
    
def getGeoData(address):
    
    base = "https://openapi.naver.com/v1/map/geocode"
    node = ""
    parameters = "?query=%s" % urllib.parse.quote(address)
    url = base + node + parameters
    
    retData = get_request_url(url)
    
    if (retData == None):
        return None
    else:
        return json.loads(retData)

# %%
for place in place_Depth_code:
    info_result = [] 
    print(place)
    
    for info_num,info in enumerate(final_dict[place]):
        print(info['place_address'])
        jsonResult = getGeoData(info['place_address'])
        
        try:
            for item in jsonResult['result']['items']:
                    final_dict[place][info_num]['lat'] =  str(item['point']['y'])
                    final_dict[place][info_num]['lon'] =  str(item['point']['x'])
        except Exception as e:
            print("예외!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
            final_dict[place][info_num]['lat'] = "NaN"
            final_dict[place][info_num]['lon']=  "NaN"    
            print(e)

# %%
with open('dish_place_tests.json', 'w', encoding="utf-8") as fp:
    json.dump(final_dict, fp, ensure_ascii=False, indent="\t")

# %%
import json

# %%
with open('dish_place_tests.json', 'r', encoding='utf-8') as fp:
    final_dict = json.load(fp)

# %%
type(final_dict)
# Out:
# dict

# %% [markdown]
# # 1. 주요시설 이름/ 주요시설 주소/ 경도/ 위도 / 카테고리

# %%
import pandas as pd

# %%
datas = DataFrame()
for info in final_dict.keys():
    data = pd.DataFrame.from_dict(final_dict[info])
    data = pd.DataFrame(data, columns=['place_name' , 'place_address', 'lat', 'lon'])
    data['category'] = info+"_food" 
    data['lat'] = data['lat'].astype(float)
    data['lon'] = data['lon'].astype(float)
    
    datas = datas.append(data)

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 100
# Data columns (total 5 columns):
# place_name       414 non-null object
# place_address    414 non-null object
# lat              407 non-null float64
# lon              407 non-null float64
# category         414 non-null object
# dtypes: float64(2), object(3)
# memory usage: 19.4+ KB

# %%
# 주요시설 id_ end number =4855

# %%
index = [i for i in range(4856, 5270)]

# %%
datas['place_id'] = index

# %%
datas
# Out:
#                       place_name          place_address        lat  \
# 0                        FR푸드시스템    서울특별시 강서구 공항대로  318  37.557800
# 1                           OK목장    서울특별시 송파구 백제고분로 547        NaN
# 2                          The만나      서울특별시 노원구 석계로 103  37.622842
# 3                    ㈜이리오어라(한정식)  서울특별시 강남구 언주로153길  12  37.522956
# 4                            가야옥      서울특별시 도봉구 도당로   2  37.658405
# 5                           가족천하    서울특별시 영등포구 가마산로 330  37.498813
# 6                           갈비둥지      서울특별시 노원구 덕릉로 692  37.659410
# 7                           갈비사랑    서울특별시 서초구 강남대로  204  37.482488
# 8                           갈비세상      서울특별시 구로구 경인로 281  37.498519
# 9                           갈비예찬      서울특별시 도봉구 노해로 259  37.651681
# 10                          감자바우      서울특별시 강남구 언주로 855  37.526828
# 11                          강강술래     서울특별시 노원구 동일로 1628  37.673847
# 12                          강강술래     서울특별시 강남구 논현로  325  37.494160
# 13                          개성면옥     서울특별시 성북구 정릉로  263  37.604111
# 14                    개성면옥(함흥냉면)      서울특별시 강서구 양천로 660  37.552123
# 15                          거북이집   서울특별시 서대문구 연희로  12-1  37.559869
# 16                           경복궁    서울특별시 송파구 올림픽로  348  37.515939
# 17                  경복궁(불고기브라더스)    서울특별시 강서구 공항대로  280  37.558025
# 18                  경인빌딩(엉터리생고기)      서울특별시 관악구 봉천로 385  37.483391
# 19                          고기굼터      서울특별시 강서구 양천로 376  37.566859
# 20                           골방집      서울특별시 강북구 한천로 926  37.634433
# 21                          공룡고기    서울특별시 금천구 시흥대로  185  37.450379
# 22                          공룡고기      서울특별시 도봉구 마들로 542  37.660094
# 23                           광양림  서울특별시 영등포구 선유로9가길  16  37.518622
# 24                        교촌1991   서울특별시 서초구 강남대로69길  8  37.501843
# 25                           궁안뜰     서울특별시 노원구 공릉로51길 7  37.628784
# 26               근린생활시설(고갯마루한정식)      서울특별시 노원구 수락산로 56  37.667333
# 27                  근린생활시설(대게나라)      서울특별시 노원구 상계로 122  37.657803
# 28                 근린생활시설(못된송아지)     서울특별시 노원구 상계로5길 26  37.657131
# 29                  근린생활시설(배밭고을)     서울특별시 노원구 동일로 1611  37.672254
# ..                           ...                    ...        ...
# 71                            주런  서울특별시 강서구 공항대로46길  89  37.552188
# 72   중림동 325-1 제2종근린생활시설(우진제임스전)    서울특별시 중구 세종대로11길 30  37.562365
# 73                       지오브레스빌딩   서울특별시 용산구 대사관로34길 22  37.532374
# 74                           지태하   서울특별시 강남구 언주로148길 14  37.520633
# 75                         진미파라곤    서울특별시 영등포구 국회대로 800  37.530902
# 76                          청산유통     서울특별시 중랑구 동일로  937  37.614008
# 77                       카페 무이무이   서울특별시 강남구 도산대로51길 19  37.524428
# 78                        카페뎀셀브쥬     서울특별시 종로구 삼일대로 388  37.569205
# 79                         카페프렌즈   서울특별시 서초구 반포대로16길 30  37.486357
# 80                           커피빈       서울특별시 중구 명동8길  9  37.563349
# 81        커피빈 압구정점(스마트 익스체인지 빌딩)   서울특별시 강남구 도산대로49길 13  37.523750
# 82             커피빈 코리아 삼성점(우창빌딩)     서울특별시 강남구 삼성로  646  37.517701
# 83                         커피스미스   서울특별시 강남구 도산대로13길 13  37.518733
# 84                         코나커피숍  서울특별시 송파구 백제고분로44길 34  37.505973
# 85                         타운플라자  서울특별시 서초구 신반포로47길 9-6  37.511261
# 86                         트라이랜드  서울특별시 서초구 서초대로77길  58  37.502581
# 87                   티에스아이디-인테리어  서울특별시 은평구 대서문길  43-14  37.656037
# 88                     파스꾸찌신촌연대점      서울특별시 서대문구 연세로 22  37.557589
# 89                프로포즈야채과일<간이장터>   서울특별시 도봉구 노해로63다길 25  37.654021
# 90                      프리미어플레이스        서울특별시 중구 중림로 40  37.557694
# 91                  피티 앤 브이-직업소개     서울특별시 영등포구 신길로 220  37.511722
# 92                      한국경제신문사옥       서울특별시 중구 청계천로 14  37.568803
# 93                        할리스커피점   서울특별시 서대문구 거북골로 31-1  37.579555
# 94                       해동수산광장점     서울특별시 광진구 광나루로 619  37.541020
# 95                        해물퓨전주점   서울특별시 광진구 아차산로31길 29  37.542364
# 96                      헐리스커피연희점     서울특별시 서대문구 연희맛로 32  37.567563
# 97                  헤라로사커피(JS빌딩)    서울특별시 강남구 도산대로  427  37.523962
# 98                            헤븐   서울특별시 강남구 봉은사로82길 29  37.511352
# 99                            호야  서울특별시 강남구 강남대로78길  22  37.495170
# 100                   효천공영-음악감상실      서울특별시 종로구 성균관로 87  37.589974
#
#             lon     category  place_id
# 0    126.842915  korean_food      4856
# 1           NaN  korean_food      4857
# 2    127.060726  korean_food      4858
# 3    127.032208  korean_food      4859
# 4    127.035329  korean_food      4860
# 5    126.896346  korean_food      4861
# 6    127.075689  korean_food      4862
# 7    127.036736  korean_food      4863
# 8    126.851831  korean_food      4864
# 9    127.036992  korean_food      4865
# 10   127.033000  korean_food      4866
# 11   127.056036  korean_food      4867
# 12   127.039504  korean_food      4868
# 13   127.012944  korean_food      4869
# 14   126.870106  korean_food      4870
# 15   126.926868  korean_food      4871
# 16   127.109050  korean_food      4872
# 17   126.838464  korean_food      4873
# 18   126.942788  korean_food      4874
# 19   126.843735  korean_food      4875
# 20   127.036962  korean_food      4876
# 21   126.901837  korean_food      4877
# 22   127.050519  korean_food      4878
# 23   126.888305  korean_food      4879
# 24   127.024649  korean_food      4880
# 25   127.076728  korean_food      4881
# 26   127.070785  korean_food      4882
# 27   127.068475  korean_food      4883
# 28   127.063255  korean_food      4884
# 29   127.055450  korean_food      4885
# ..          ...          ...       ...
# 71   126.851122   other_food      5240
# 72   126.974205   other_food      5241
# 73   127.005785   other_food      5242
# 74   127.036183   other_food      5243
# 75   126.921121   other_food      5244
# 76   127.076498   other_food      5245
# 77   127.037653   other_food      5246
# 78   126.988013   other_food      5247
# 79   127.012385   other_food      5248
# 80   126.984708   other_food      5249
# 81   127.037004   other_food      5250
# 82   127.051193   other_food      5251
# 83   127.022997   other_food      5252
# 84   127.112397   other_food      5253
# 85   127.019336   other_food      5254
# 86   127.024407   other_food      5255
# 87   126.949399   other_food      5256
# 88   126.937094   other_food      5257
# 89   127.046094   other_food      5258
# 90   126.967400   other_food      5259
# 91   126.910306   other_food      5260
# 92   126.978838   other_food      5261
# 93   126.924192   other_food      5262
# 94   127.096638   other_food      5263
# 95   127.069702   other_food      5264
# 96   126.930806   other_food      5265
# 97   127.042587   other_food      5266
# 98   127.055573   other_food      5267
# 99   127.031185   other_food      5268
# 100  126.998293   other_food      5269
#
# [414 rows x 6 columns]

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 100
# Data columns (total 6 columns):
# place_name       414 non-null object
# place_address    414 non-null object
# lat              407 non-null float64
# lon              407 non-null float64
# category         414 non-null object
# place_id         414 non-null int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 22.6+ KB

# %%
datas.to_csv("dish_place.csv",encoding = "utf-8")

# %% [markdown]
# # 2. 주요시설 이름/주요시설물 설치/ (이용가능 /이용불편)

# %%
data_facility = DataFrame()
for test in final_dict.keys():
    for i,category in enumerate(final_dict[test]):
        
        data_pre_facility = pd.DataFrame.from_dict(category['facility_detail_info'])
        data_pre_facility = pd.DataFrame(data_pre_facility, columns=['facility_available_name', 'facility_is_available'])
        data_pre_facility['place_name'] = category['place_name']

        data_pre_facility['place_id'] = datas.iloc[i,5]
          
        data_facility = data_facility.append(data_pre_facility)
        
data_facility['facility_available_name'] += "_"+data_facility['place_name']

# %%
data_facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 987 entries, 0 to 2
# Data columns (total 4 columns):
# facility_available_name    987 non-null object
# facility_is_available      987 non-null object
# place_name                 987 non-null object
# place_id                   987 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 38.6+ KB

# %%
data_facility.reset_index(inplace=True)

# %%
x = data_facility.apply(lambda x : str(x['place_id'])+"-"+str(x['index']),axis=1)

# %%
data_facility['facility_id'] =x

# %%
data_facility.drop(columns=['index'], inplace=True)

# %%
data_facility
# Out:
#          facility_available_name facility_is_available      place_name  \
# 0            장애인 전용 주차구역_FR푸드시스템                  이용가능         FR푸드시스템
# 1           주출입구 높이차이 제거_FR푸드시스템                  이용가능         FR푸드시스템
# 2                  주출입구 접근로_OK목장                  이용가능            OK목장
# 3               장애인 전용 주차구역_OK목장                  이용가능            OK목장
# 4                 주출입구 접근로_The만나                  이용불편           The만나
# 5              장애인 전용 주차구역_The만나                  이용가능           The만나
# 6             주출입구 높이차이 제거_The만나                  이용불편           The만나
# 7           주출입구 접근로_㈜이리오어라(한정식)                  이용가능     ㈜이리오어라(한정식)
# 8        장애인 전용 주차구역_㈜이리오어라(한정식)                  이용가능     ㈜이리오어라(한정식)
# 9                   주출입구 접근로_가야옥                  이용불편             가야옥
# 10               장애인 전용 주차구역_가야옥                  이용가능             가야옥
# 11              주출입구 높이차이 제거_가야옥                  이용가능             가야옥
# 12                 주출입구 접근로_가족천하                  이용가능            가족천하
# 13                 주출입구 접근로_갈비둥지                  이용불편            갈비둥지
# 14              장애인 전용 주차구역_갈비둥지                  이용불편            갈비둥지
# 15             주출입구 높이차이 제거_갈비둥지                  이용불편            갈비둥지
# 16                 주출입구 접근로_갈비사랑                  이용불편            갈비사랑
# 17             주출입구 높이차이 제거_갈비사랑                  이용가능            갈비사랑
# 18                 주출입구 접근로_갈비세상                  이용가능            갈비세상
# 19             주출입구 높이차이 제거_갈비세상                  이용가능            갈비세상
# 20                 주출입구 접근로_갈비예찬                  이용불편            갈비예찬
# 21             주출입구 높이차이 제거_갈비예찬                  이용불편            갈비예찬
# 22                 주출입구 접근로_감자바우                  이용가능            감자바우
# 23             주출입구 높이차이 제거_감자바우                  이용가능            감자바우
# 24                 주출입구 접근로_강강술래                  이용불편            강강술래
# 25              장애인 전용 주차구역_강강술래                  이용불편            강강술래
# 26             주출입구 높이차이 제거_강강술래                  이용가능            강강술래
# 27                 주출입구 접근로_강강술래                  이용가능            강강술래
# 28                 장애인용 관람석_강강술래                  이용가능            강강술래
# 29                 주출입구 접근로_개성면옥                  이용가능            개성면옥
# ..                           ...                   ...             ...
# 957       주출입구 높이차이 제거_파스꾸찌신촌연대점                  이용가능       파스꾸찌신촌연대점
# 958      주출입구 접근로_프로포즈야채과일<간이장터>                  이용가능  프로포즈야채과일<간이장터>
# 959   장애인 전용 주차구역_프로포즈야채과일<간이장터>                  이용가능  프로포즈야채과일<간이장터>
# 960  주출입구 높이차이 제거_프로포즈야채과일<간이장터>                  이용가능  프로포즈야채과일<간이장터>
# 961            주출입구 접근로_프리미어플레이스                  이용가능        프리미어플레이스
# 962        주출입구 높이차이 제거_프리미어플레이스                  이용가능        프리미어플레이스
# 963        주출입구 접근로_피티 앤 브이-직업소개                  이용불편    피티 앤 브이-직업소개
# 964     장애인 전용 주차구역_피티 앤 브이-직업소개                  이용가능    피티 앤 브이-직업소개
# 965            주출입구 접근로_한국경제신문사옥                  이용가능        한국경제신문사옥
# 966         장애인 전용 주차구역_한국경제신문사옥                  이용불편        한국경제신문사옥
# 967        주출입구 높이차이 제거_한국경제신문사옥                  이용불편        한국경제신문사옥
# 968              주출입구 접근로_할리스커피점                  이용가능          할리스커피점
# 969           장애인 전용 주차구역_할리스커피점                  이용가능          할리스커피점
# 970          주출입구 높이차이 제거_할리스커피점                  이용가능          할리스커피점
# 971             주출입구 접근로_해동수산광장점                  이용불편         해동수산광장점
# 972         주출입구 높이차이 제거_해동수산광장점                  이용가능         해동수산광장점
# 973              주출입구 접근로_해물퓨전주점                  이용불편          해물퓨전주점
# 974           장애인 전용 주차구역_해물퓨전주점                  이용가능          해물퓨전주점
# 975          주출입구 높이차이 제거_해물퓨전주점                  이용가능          해물퓨전주점
# 976            주출입구 접근로_헐리스커피연희점                  이용가능        헐리스커피연희점
# 977        주출입구 접근로_헤라로사커피(JS빌딩)                  이용가능    헤라로사커피(JS빌딩)
# 978     장애인 전용 주차구역_헤라로사커피(JS빌딩)                  이용불편    헤라로사커피(JS빌딩)
# 979                  주출입구 접근로_헤븐                  이용가능              헤븐
# 980               장애인 전용 주차구역_헤븐                  이용가능              헤븐
# 981                  주출입구 접근로_호야                  이용가능              호야
# 982               장애인 전용 주차구역_호야                  이용가능              호야
# 983              주출입구 높이차이 제거_호야                  이용가능              호야
# 984          주출입구 접근로_효천공영-음악감상실                  이용가능      효천공영-음악감상실
# 985       장애인 전용 주차구역_효천공영-음악감상실                  이용가능      효천공영-음악감상실
# 986      주출입구 높이차이 제거_효천공영-음악감상실                  이용불편      효천공영-음악감상실
#
#      place_id facility_id
# 0        4856      4856-0
# 1        4856      4856-1
# 2        4857      4857-0
# 3        4857      4857-1
# 4        4858      4858-0
# 5        4858      4858-1
# 6        4858      4858-2
# 7        4859      4859-0
# 8        4859      4859-1
# 9        4860      4860-0
# 10       4860      4860-1
# 11       4860      4860-2
# 12       4861      4861-0
# 13       4862      4862-0
# 14       4862      4862-1
# 15       4862      4862-2
# 16       4863      4863-0
# 17       4863      4863-1
# 18       4864      4864-0
# 19       4864      4864-1
# 20       4865      4865-0
# 21       4865      4865-1
# 22       4866      4866-0
# 23       4866      4866-1
# 24       4867      4867-0
# 25       4867      4867-1
# 26       4867      4867-2
# 27       4868      4868-0
# 28       4868      4868-1
# 29       4869      4869-0
# ..        ...         ...
# 957      4944      4944-2
# 958      4945      4945-0
# 959      4945      4945-1
# 960      4945      4945-2
# 961      4946      4946-0
# 962      4946      4946-1
# 963      4947      4947-0
# 964      4947      4947-1
# 965      4948      4948-0
# 966      4948      4948-1
# 967      4948      4948-2
# 968      4949      4949-0
# 969      4949      4949-1
# 970      4949      4949-2
# 971      4950      4950-0
# 972      4950      4950-1
# 973      4951      4951-0
# 974      4951      4951-1
# 975      4951      4951-2
# 976      4952      4952-0
# 977      4953      4953-0
# 978      4953      4953-1
# 979      4954      4954-0
# 980      4954      4954-1
# 981      4955      4955-0
# 982      4955      4955-1
# 983      4955      4955-2
# 984      4956      4956-0
# 985      4956      4956-1
# 986      4956      4956-2
#
# [987 rows x 5 columns]

# %%
pd.DataFrame.to_csv(data_facility, "dish_place_facility_available.csv", encoding = "utf-8")

# %% [markdown]
# # 3. 주요시설 상세정보 / 주요시설물 설치

# %%
import re

# %%
data_facility_detail = DataFrame()
for test in final_dict.keys():
    for category in final_dict[test]:

        for facility in category['facility_detail_info']:
            a = [info for info in facility['facility_info']]

            data_pre_facility = pd.DataFrame.from_dict(a)
           
            data_pre_facility['facility_available_name'] = facility['facility_available_name']+"_"+category['place_name']
            get_facility_id = data_facility[data_pre_facility['facility_available_name'][0] == data_facility['facility_available_name']]['facility_id']
            get_facility_id = re.findall(r'([0-9]+-[0-9]+)',str(get_facility_id))
            get_facility_id = [get_facility_id[0] for i in data_pre_facility['facility_available_name']]
            data_pre_facility['facility_id'] = get_facility_id
            data_facility_detail = data_facility_detail.append(data_pre_facility)

# %%
data_facility_detail = data_facility_detail.rename(index=str, columns={0: "facility_detail_info"})

# %%
data_facility_detail = data_facility_detail.reset_index(drop=True)

# %%
data_facility_detail
# Out:
#        facility_detail_info   facility_available_name facility_id
# 0                    총주차대수5       장애인 전용 주차구역_FR푸드시스템      4856-0
# 1     단차없음 또는 경사로 1/12이하 설치      주출입구 높이차이 제거_FR푸드시스템      4856-1
# 2               유효폭 1.2m 이상      주출입구 높이차이 제거_FR푸드시스템      4856-1
# 3                    손잡이 설치      주출입구 높이차이 제거_FR푸드시스템      4856-1
# 4                       평탄함             주출입구 접근로_OK목장      4857-0
# 5                      단차없음             주출입구 접근로_OK목장      4857-0
# 6               유효폭 1.2m 이상             주출입구 접근로_OK목장      4857-0
# 7                기울기 1/18이하             주출입구 접근로_OK목장      4857-0
# 8                   보/차도 구분             주출입구 접근로_OK목장      4857-0
# 9                   총주차대수30          장애인 전용 주차구역_OK목장      4857-1
# 10                전용주차대수  3          장애인 전용 주차구역_OK목장      4857-1
# 11           출입구와 가까운 곳에 설치          장애인 전용 주차구역_OK목장      4857-1
# 12            크기 확보(3.3*5m)          장애인 전용 주차구역_OK목장      4857-1
# 13                 안내표지판 설치          장애인 전용 주차구역_OK목장      4857-1
# 14                      평탄함            주출입구 접근로_The만나      4858-0
# 15                     단차없음            주출입구 접근로_The만나      4858-0
# 16              유효폭 1.2m 이상            주출입구 접근로_The만나      4858-0
# 17               기울기 1/18이하            주출입구 접근로_The만나      4858-0
# 18                보/차도 구분없음            주출입구 접근로_The만나      4858-0
# 19                  상세정보 없음         장애인 전용 주차구역_The만나      4858-1
# 20            경사로 1/12초과 설치        주출입구 높이차이 제거_The만나      4858-2
# 21              유효폭 1.2m 미만        주출입구 높이차이 제거_The만나      4858-2
# 22                   손잡이 설치        주출입구 높이차이 제거_The만나      4858-2
# 23                  상세정보 없음      주출입구 접근로_㈜이리오어라(한정식)      4859-0
# 24                  총주차대수31   장애인 전용 주차구역_㈜이리오어라(한정식)      4859-1
# 25                전용주차대수  1   장애인 전용 주차구역_㈜이리오어라(한정식)      4859-1
# 26           출입구와 가까운 곳에 설치   장애인 전용 주차구역_㈜이리오어라(한정식)      4859-1
# 27            크기 확보(3.3*5m)   장애인 전용 주차구역_㈜이리오어라(한정식)      4859-1
# 28                 안내표지판 설치   장애인 전용 주차구역_㈜이리오어라(한정식)      4859-1
# 29                  평탄하지 않음              주출입구 접근로_가야옥      4860-0
# ...                     ...                       ...         ...
# 2822                 총주차대수5        장애인 전용 주차구역_해물퓨전주점      4951-1
# 2823  단차없음 또는 경사로 1/12이하 설치       주출입구 높이차이 제거_해물퓨전주점      4951-2
# 2824            유효폭 1.2m 이상       주출입구 높이차이 제거_해물퓨전주점      4951-2
# 2825                 손잡이 설치       주출입구 높이차이 제거_해물퓨전주점      4951-2
# 2826                상세정보 없음         주출입구 접근로_헐리스커피연희점      4952-0
# 2827                    평탄함     주출입구 접근로_헤라로사커피(JS빌딩)      4953-0
# 2828                   단차없음     주출입구 접근로_헤라로사커피(JS빌딩)      4953-0
# 2829            유효폭 1.2m 이상     주출입구 접근로_헤라로사커피(JS빌딩)      4953-0
# 2830             기울기 1/18이하     주출입구 접근로_헤라로사커피(JS빌딩)      4953-0
# 2831                보/차도 구분     주출입구 접근로_헤라로사커피(JS빌딩)      4953-0
# 2832                총주차대수16  장애인 전용 주차구역_헤라로사커피(JS빌딩)      4953-1
# 2833              전용주차대수  1  장애인 전용 주차구역_헤라로사커피(JS빌딩)      4953-1
# 2834         출입구와 가까운 곳에 설치  장애인 전용 주차구역_헤라로사커피(JS빌딩)      4953-1
# 2835          크기 확보(3.3*5m)  장애인 전용 주차구역_헤라로사커피(JS빌딩)      4953-1
# 2836              안내표지판 미설치  장애인 전용 주차구역_헤라로사커피(JS빌딩)      4953-1
# 2837                    평탄함               주출입구 접근로_헤븐      4954-0
# 2838                   단차없음               주출입구 접근로_헤븐      4954-0
# 2839            유효폭 1.2m 이상               주출입구 접근로_헤븐      4954-0
# 2840             기울기 1/18이하               주출입구 접근로_헤븐      4954-0
# 2841                보/차도 구분               주출입구 접근로_헤븐      4954-0
# 2842                 총주차대수4            장애인 전용 주차구역_헤븐      4954-1
# 2843                상세정보 없음               주출입구 접근로_호야      4955-0
# 2844                 총주차대수4            장애인 전용 주차구역_호야      4955-1
# 2845  단차없음 또는 경사로 1/12이하 설치           주출입구 높이차이 제거_호야      4955-2
# 2846            유효폭 1.2m 이상           주출입구 높이차이 제거_호야      4955-2
# 2847                상세정보 없음       주출입구 접근로_효천공영-음악감상실      4956-0
# 2848                 총주차대수8    장애인 전용 주차구역_효천공영-음악감상실      4956-1
# 2849              전용주차대수  1    장애인 전용 주차구역_효천공영-음악감상실      4956-1
# 2850          경사로 1/12초과 설치   주출입구 높이차이 제거_효천공영-음악감상실      4956-2
# 2851            유효폭 1.2m 이상   주출입구 높이차이 제거_효천공영-음악감상실      4956-2
#
# [2852 rows x 3 columns]

# %%
pd.DataFrame.to_csv(data_facility_detail, "dish_place_facility_detail_info.csv",encoding = "utf-8")
