# %%
import pandas as pd

# %%
zzang_place = pd.read_csv('ZZANG_PLACE.csv')

# %%
zzang_facility = pd.read_csv('ZZANG_FACILITY.csv')

# %%
zzang_facility_info = pd.read_csv('ZZANG_FACILITY_INFO_BUT_ONLY_YJS.csv')

# %%
zzang_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17236 entries, 0 to 17235
# Data columns (total 7 columns):
# Unnamed: 0       17236 non-null int64
# category         17236 non-null object
# lat              17236 non-null object
# lon              17236 non-null object
# place_address    16912 non-null object
# place_id         17236 non-null int64
# place_name       17236 non-null object
# dtypes: int64(2), object(5)
# memory usage: 942.7+ KB

# %%
zzang_place[zzang_place.duplicated(subset=['lat','lon'],keep=False)].sort_values('lat')
# Out:
#        Unnamed: 0                  category                 lat  \
# 6660         6660                      bank   37.43498573000639
# 15191       15191                    church   37.43498573000639
# 8059         8059            welfare/senior   37.43498573000639
# 12373       12373             shopping/mart   37.43498573000639
# 11347       11347            welfare/senior   37.43498573000639
# 14956       14956             shopping/mart   37.43498573000639
# 9607         9607            daycare center   37.43498573000639
# 11009       11009              concert hall   37.43498573000639
# 8945         8945              meeting hall   37.43498573000639
# 13160       13160            daycare center   37.43854915499457
# 9579         9579                  hospital   37.43854915499457
# 7597         7597            public parking   37.44787766409346
# 6382         6382            daycare center   37.44787766409346
# 6865         6865            daycare center   37.44850477634772
# ...

# %%
zzang_place[zzang_place.lat =='성산']
# Out:
#        Unnamed: 0 category lat lon place_address  place_id place_name
# 17077       17077   subway  성산  성산           NaN       165         성산

# %%
zzang_place.drop([17077],inplace=True)

# %%
zzang_place[zzang_place.lat =='성산']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, category, lat, lon, place_address, place_id, place_name]
# Index: []

# %%
zzang_place[zzang_place.lat.str.contains('산')]
# Out:
#        Unnamed: 0 category  lat  lon place_address  place_id place_name
# 17043       17043   subway  봉화산  봉화산           NaN       131        봉화산

# %%
zzang_place.drop([16992],inplace=True)

# %%
zzang_place.drop([17043],inplace=True)

# %%
zzang_place[zzang_place.lat.str.contains('[ㄱ-ㅎ가-힣ㅏ-ㅢ]')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, category, lat, lon, place_address, place_id, place_name]
# Index: []

# %%
zzang_place.lat =zzang_place.lat.astype('float64')

# %%
zzang_place.lon =zzang_place.lon.astype('float64')

# %%
zzang_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17233 entries, 0 to 17235
# Data columns (total 7 columns):
# Unnamed: 0       17233 non-null int64
# category         17233 non-null object
# lat              17233 non-null float64
# lon              17233 non-null float64
# place_address    16912 non-null object
# place_id         17233 non-null int64
# place_name       17233 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
zzang_place.to_csv('ZZANG_PLACE.csv')
