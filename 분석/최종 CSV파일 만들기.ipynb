# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../Jeungmin/clean_table_with_gu.csv')

# %%
data.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], inplace= True)

# %%
data.head()
# Out:
#   category        lat         lon place_address  place_id place_name  \
# 0   subway  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 1   subway  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 2   subway  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 3   subway  37.480890  126.882574     서울특별시 금천구         1    가산디지털단지
# 4   subway  37.480890  126.882574     서울특별시 금천구         1    가산디지털단지
#
#   facility_available_name facility_is_available  facility_id   Gu
# 0                     화장실                  이용가능       900000  송파구
# 1                   엘리베이터                  이용가능       900001  송파구
# 2                  휠체어리프트                  이용가능       900002  송파구
# 3                  에스켈레이터                  이용가능       900003  금천구
# 4                     화장실                  이용가능       900004  금천구

# %%
data = data[data.facility_available_name != "일반사항"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45325 entries, 0 to 46524
# Data columns (total 10 columns):
# category                   45325 non-null object
# lat                        45325 non-null float64
# lon                        45325 non-null float64
# place_address              45325 non-null object
# place_id                   45325 non-null int64
# place_name                 45325 non-null object
# facility_available_name    45325 non-null object
# facility_is_available      15032 non-null object
# facility_id                45325 non-null int64
# Gu                         45315 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 3.8+ MB

# %%
data.isna().count()
# Out:
# category                   45325
# lat                        45325
# lon                        45325
# place_address              45325
# place_id                   45325
# place_name                 45325
# facility_available_name    45325
# facility_is_available      45325
# facility_id                45325
# Gu                         45325
# dtype: int64

# %%
# 한글명세
facility_name_ko={"exhibition center" : "전시장",
"park" :"공원",
"gym" : "체육관(운동장)",
"movie/concerthall" :"영화관/공연장",
"shopping/mart" :"수퍼마켓·일용품 등의 도매·소매시장",
"beauty/hair" : "미용원·목욕장",
"hotel" : "일반숙박시설",
"library" : "도서관",
"restaurant" : "일반음식점",
"police station" : "경찰서",
"post office" : "우체국",
"bank" : "은행",
"health center" : "보건소",
"community service center" : "지역자치센터",
"hospital" : "종합병원",
"toilet/small" : "간이화장실",
"toilet/open" : "공중화장실",
"toilet/public" : "공중화장실",
"welfare/child" : "아동복지시설",
"welfare/senior" : "노인복지시설",
"welfare/disabled" : "장애인복지시설",
"welfare/etc" : "이외 사회복지시설",
"daycare center" : "어린이집",
"special-education school" : "특수학교",
"kindergarten" : "유치원",
"elementary school" : "초등학교",
"junior high school" : "중학교",
"high school" : "고등학교",
"university" : "대학교",
"education/job" : "교육원·직업훈련소·학원",
"training facility" : "수련시설",
"subway" : "지하철",
"publicparking" : "주차장",
"church" : "종교집회장",}



# 여가생활 
play_list = ["exhibition center", "park", "gym", "movie/concerthall" ,"shopping/mart" , "beauty/hair",
 "hotel" ,"library" ,"restaurant" ]

# 대표시설
big6_list = ["police station" , "post office", "bank" ,"health center" ,
         "community service center" , "hospital" ]

# 화장실
toilet_list = [ "toilet/small" , "toilet/open", "toilet/public"]

# 복지시설
welfare_list = ["welfare/child",
"welfare/senior",
"welfare/disabled",
"welfare/etc",
]

# 학교 
school_list = ["daycare center",
"special-education school",
"kindergarten",
"elementary school",
"junior high school",
"high school",
"university",
]

# 학원
education_list = ["education/job"
"training facility"]

# 교통 
trafic_list = ["subway",
"publicparking"]

# 종교 
list = ["church"]


# 업데이트
facility_name_ko.update({"toilet" : "화장실", "welfare" : "복지시설", "school":"학교", "education": "학원"})

# %%
def category_sum(dataframe,replace_target,replace_str):
    print("전체 category 개수")
    print(len(dataframe.category.unique()))
    print()
    print("이 전",replace_str,"해당 category 개수 : ")
    print(dataframe.loc[dataframe.category == replace_str].apply(len))
    dataframe_replace = dataframe[dataframe.loc[:, 'category'] == replace_target]
    dataframe_replace.category = replace_str
    dataframe[dataframe.loc[:, 'category'] == replace_target] = dataframe_replace
    print()
    print("이 후",replace_str,"해당 category 개수 : ")
    print(dataframe.loc[dataframe.category == replace_str].apply(len))
    print()
    print("전체 category 개수")
    print(len(dataframe.category.unique()))
    return dataframe

# %%
def category_place_sum(dataframe,replace_target,replace_str):
    dataframe_replace = dataframe[dataframe.loc[:, 'category'] == replace_target]
    dataframe_replace.category = replace_str
    dataframe[dataframe.loc[:, 'category'] == replace_target] = dataframe_replace
    return dataframe

# %%
def reg_name_change(dataframe, category_str, reg, change_category):
    a = dataframe[dataframe.category == category_str]
    b = a[a.place_name.str.contains(reg)]
    b.category = change_category
    dataframe.iloc[b.index] =b
    return dataframe

# %%
# 대분류로 묶은 dataframe  
# 화장실, 학교, 복지시설, 학원 통합

# 업데이트
facility_name_ko.update({"toilet" : "화장실", "welfare" : "복지시설", "school":"학교", "education": "학원"})
large_split_data= data.copy()
total_list = [ toilet_list, welfare_list, school_list, education_list ]
total_rename= ["toilet", "welfare", "school", "education"]
for i,rows in enumerate(total_list):
    for row in rows:
        large_split_data = category_sum(large_split_data, row, total_rename[i])
# Out:
# 전체 category 개수
# 34
#
# 이 전 toilet 해당 category 개수 :
# category                  NaN
# lat                       NaN
# lon                       NaN
# place_address             NaN
# place_id                  NaN
# place_name                NaN
# facility_available_name   NaN
# facility_is_available     NaN
# facility_id               NaN
# Gu                        NaN
# dtype: float64
#
# 이 후 toilet 해당 category 개수 :
# category                   82
# lat                        82
# lon                        82
# place_address              82
# place_id                   82
# place_name                 82
# facility_available_name    82
# facility_is_available      82
# facility_id                82
# Gu                         82
# dtype: int64
#
# 전체 category 개수
# 34
# 전체 category 개수
# 34
#
# 이 전 toilet 해당 category 개수 :
# category                   82
# lat                        82
# lon                        82
# place_address              82
# place_id                   82
# place_name                 82
# facility_available_name    82
# facility_is_available      82
# facility_id                82
# Gu                         82
# dtype: int64
#
# 이 후 toilet 해당 category 개수 :
# category                   7172
# lat                        7172
# lon                        7172
# place_address              7172
# place_id                   7172
# place_name                 7172
# facility_available_name    7172
# facility_is_available      7172
# facility_id                7172
# Gu                         7172
# dtype: int64
#
# 전체 category 개수
# 33
# 전체 category 개수
# 33
#
# 이 전 toilet 해당 category 개수 :
# category                   7172
# lat                        7172
# lon                        7172
# place_address              7172
# place_id                   7172
# place_name                 7172
# facility_available_name    7172
# facility_is_available      7172
# facility_id                7172
# Gu                         7172
# dtype: int64
#
# 이 후 toilet 해당 category 개수 :
# category                   7406
# lat                        7406
# lon                        7406
# place_address              7406
# place_id                   7406
# place_name                 7406
# facility_available_name    7406
# facility_is_available      7406
# facility_id                7406
# Gu                         7406
# dtype: int64
#
# 전체 category 개수
# 32
# 전체 category 개수
# 32
#
# 이 전 welfare 해당 category 개수 :
# category                  NaN
# lat                       NaN
# lon                       NaN
# place_address             NaN
# place_id                  NaN
# place_name                NaN
# facility_available_name   NaN
# facility_is_available     NaN
# facility_id               NaN
# Gu                        NaN
# dtype: float64
#
# 이 후 welfare 해당 category 개수 :
# category                   271
# lat                        271
# lon                        271
# place_address              271
# place_id                   271
# place_name                 271
# facility_available_name    271
# facility_is_available      271
# facility_id                271
# Gu                         271
# dtype: int64
#
# 전체 category 개수
# 32
# 전체 category 개수
# 32
#
# 이 전 welfare 해당 category 개수 :
# category                   271
# lat                        271
# lon                        271
# place_address              271
# place_id                   271
# place_name                 271
# facility_available_name    271
# facility_is_available      271
# facility_id                271
# Gu                         271
# dtype: int64
#
# 이 후 welfare 해당 category 개수 :
# category                   2883
# lat                        2883
# lon                        2883
# place_address              2883
# place_id                   2883
# place_name                 2883
# facility_available_name    2883
# facility_is_available      2883
# facility_id                2883
# Gu                         2883
# dtype: int64
#
# 전체 category 개수
# 31
# 전체 category 개수
# 31
#
# 이 전 welfare 해당 category 개수 :
# category                   2883
# lat                        2883
# lon                        2883
# place_address              2883
# place_id                   2883
# place_name                 2883
# facility_available_name    2883
# facility_is_available      2883
# facility_id                2883
# Gu                         2883
# dtype: int64
#
# 이 후 welfare 해당 category 개수 :
# category                   4303
# lat                        4303
# lon                        4303
# place_address              4303
# place_id                   4303
# place_name                 4303
# facility_available_name    4303
# facility_is_available      4303
# facility_id                4303
# Gu                         4303
# dtype: int64
#
# 전체 category 개수
# 30
# 전체 category 개수
# 30
#
# 이 전 welfare 해당 category 개수 :
# category                   4303
# lat                        4303
# lon                        4303
# place_address              4303
# place_id                   4303
# place_name                 4303
# facility_available_name    4303
# facility_is_available      4303
# facility_id                4303
# Gu                         4303
# dtype: int64
#
# 이 후 welfare 해당 category 개수 :
# category                   5918
# lat                        5918
# lon                        5918
# place_address              5918
# place_id                   5918
# place_name                 5918
# facility_available_name    5918
# facility_is_available      5918
# facility_id                5918
# Gu                         5918
# dtype: int64
#
# 전체 category 개수
# 29
# 전체 category 개수
# 29
#
# 이 전 school 해당 category 개수 :
# category                  NaN
# lat                       NaN
# lon                       NaN
# place_address             NaN
# place_id                  NaN
# place_name                NaN
# facility_available_name   NaN
# facility_is_available     NaN
# facility_id               NaN
# Gu                        NaN
# dtype: float64
#
# 이 후 school 해당 category 개수 :
# category                   2888
# lat                        2888
# lon                        2888
# place_address              2888
# place_id                   2888
# place_name                 2888
# facility_available_name    2888
# facility_is_available      2888
# facility_id                2888
# Gu                         2888
# dtype: int64
#
# 전체 category 개수
# 29
# 전체 category 개수
# 29
#
# 이 전 school 해당 category 개수 :
# category                   2888
# lat                        2888
# lon                        2888
# place_address              2888
# place_id                   2888
# place_name                 2888
# facility_available_name    2888
# facility_is_available      2888
# facility_id                2888
# Gu                         2888
# dtype: int64
#
# 이 후 school 해당 category 개수 :
# category                   2999
# lat                        2999
# lon                        2999
# place_address              2999
# place_id                   2999
# place_name                 2999
# facility_available_name    2999
# facility_is_available      2999
# facility_id                2999
# Gu                         2999
# dtype: int64
#
# 전체 category 개수
# 28
# 전체 category 개수
# 28
#
# 이 전 school 해당 category 개수 :
# category                   2999
# lat                        2999
# lon                        2999
# place_address              2999
# place_id                   2999
# place_name                 2999
# facility_available_name    2999
# facility_is_available      2999
# facility_id                2999
# Gu                         2999
# dtype: int64
#
# 이 후 school 해당 category 개수 :
# category                   3393
# lat                        3393
# lon                        3393
# place_address              3393
# place_id                   3393
# place_name                 3393
# facility_available_name    3393
# facility_is_available      3393
# facility_id                3393
# Gu                         3393
# dtype: int64
#
# 전체 category 개수
# 27
# 전체 category 개수
# 27
#
# 이 전 school 해당 category 개수 :
# category                   3393
# lat                        3393
# lon                        3393
# place_address              3393
# place_id                   3393
# place_name                 3393
# facility_available_name    3393
# facility_is_available      3393
# facility_id                3393
# Gu                         3393
# dtype: int64
#
# 이 후 school 해당 category 개수 :
# category                   5586
# lat                        5586
# lon                        5586
# place_address              5586
# place_id                   5586
# place_name                 5586
# facility_available_name    5586
# facility_is_available      5586
# facility_id                5586
# Gu                         5586
# dtype: int64
#
# 전체 category 개수
# 26
# 전체 category 개수
# 26
#
# 이 전 school 해당 category 개수 :
# category                   5586
# lat                        5586
# lon                        5586
# place_address              5586
# place_id                   5586
# place_name                 5586
# facility_available_name    5586
# facility_is_available      5586
# facility_id                5586
# Gu                         5586
# dtype: int64
# 이 후 school 해당 category 개수 :
# category                   6543
# lat                        6543
# lon                        6543
# place_address              6543
# place_id                   6543
# place_name                 6543
# facility_available_name    6543
# facility_is_available      6543
# facility_id                6543
# Gu                         6543
# dtype: int64
#
# 전체 category 개수
# 25
# 전체 category 개수
# 25
#
# 이 전 school 해당 category 개수 :
# category                   6543
# lat                        6543
# lon                        6543
# place_address              6543
# place_id                   6543
# place_name                 6543
# facility_available_name    6543
# facility_is_available      6543
# facility_id                6543
# Gu                         6543
# dtype: int64
#
# 이 후 school 해당 category 개수 :
# category                   7486
# lat                        7486
# lon                        7486
# place_address              7486
# place_id                   7486
# place_name                 7486
# facility_available_name    7486
# facility_is_available      7486
# facility_id                7486
# Gu                         7486
# dtype: int64
#
# 전체 category 개수
# 24
# 전체 category 개수
# 24
#
# 이 전 school 해당 category 개수 :
# category                   7486
# lat                        7486
# lon                        7486
# place_address              7486
# place_id                   7486
# place_name                 7486
# facility_available_name    7486
# facility_is_available      7486
# facility_id                7486
# Gu                         7486
# dtype: int64
#
# 이 후 school 해당 category 개수 :
# category                   7856
# lat                        7856
# lon                        7856
# place_address              7856
# place_id                   7856
# place_name                 7856
# facility_available_name    7856
# facility_is_available      7856
# facility_id                7856
# Gu                         7856
# dtype: int64
#
# 전체 category 개수
# 23
# 전체 category 개수
# 23
#
# 이 전 education 해당 category 개수 :
# category                  NaN
# lat                       NaN
# lon                       NaN
# place_address             NaN
# place_id                  NaN
# place_name                NaN
# facility_available_name   NaN
# facility_is_available     NaN
# facility_id               NaN
# Gu                        NaN
# dtype: float64
#
# 이 후 education 해당 category 개수 :
# category                  NaN
# lat                       NaN
# lon                       NaN
# place_address             NaN
# place_id                  NaN
# place_name                NaN
# facility_available_name   NaN
# facility_is_available     NaN
# facility_id               NaN
# Gu                        NaN
# dtype: float64
#
# 전체 category 개수
# 23

# %% [markdown]
# # 시설이름 변경 및 시설이름 통합 컬럼

# %%
data = data[data.facility_available_name != '비치용품']

# %%
data = data[data.facility_available_name != '해당시설 층수']

# %%
data = data[data.facility_available_name != '대변기']

# %%
data = data[data.facility_available_name != '소변기']

# %%
# 시설명 수정 
facility_available_name = {
'주출입구 접근로' : '주출입구 접근로',
'주출입구 높이차이 제거' : '주출입구 높이차이 제거',
'출입구(문)' : '자동 출입구(문)',
'경보 및 피난설비' : '경보 및 피난설비',
'유도 및 안내 설비' : '경보 및 피난설비',
'장애인 전용 주차구역' : '장애인 전용 주차구역',
'장애인전용주차구역' : '장애인 전용 주차구역', 
'객실 및 침실' : '객실 및 침실', 
'욕실' : '욕실',
'샤워실 및 탈의실' : '샤워실 및 탈의실',
'세면대' : '세면대',
'장애인용 화장실' : '장애인용 화장실',    
'남성용-장애인용대변기' : '남성용-장애인용대변기',
'남성용-어린이용소변기' : '남성용-어린이용소변기' ,
'남성용-장애인용소변기' : '남성용-장애인용소변기',
'남성용-어린이용대변기' : '남성용-어린이용대변기' , 
'여성용-어린이용대변기' : '여성용-어린이용대변기', 
'남녀공용화장실' :'남녀공용화장실', 
'남성용-대변기' : '남성용-장애인용대변기' , 
'여성용-대변기' : '여성용-장애인용대변기',    
'여성용-장애인용대변기' : '여성용-장애인용대변기',     
'남성용-소변기' :'남성용-장애인용소변기', 
'매표소' : '자동 판매기', 
'접수대 및 작업대' : '접수대 및 작업대',
'장애인용 관람석' : '장애인용 관람석',
'관람석 및 열람석' : '장애인용 관람석',
'복도' : '점자블록', 
'점자블록' : '점자블록',     
'장애인용 승강기' : '장애인용 승강기',
'계단 또는 승강설비' : '장애인용 승강기',
'계단핸드레일' : '장애인용 승강기',
'승강설비' : '장애인용 승강기',
' 음료대' : '음료대',
' 판매기' : '자동 판매기',
'화장실' : '장애인용 화장실',
'엘리베이터': '장애인용 승강기',
'휠체어리프트': '휠체어리프트',
'에스켈레이터':'휠체어리프트',
'수평보행기':'수평보행기'}

# %%
data['facility_available_name'] = data.facility_available_name.apply(lambda x : facility_available_name[x])

# %%
total_facility_available_name = {
'주출입구 접근로' : '주출입구 접근로',
'주출입구 높이차이 제거' : '주출입구 높이차이 제거',
'자동 출입구(문)' : '자동 출입구(문)',
'경보 및 피난설비' : '경보 및 피난설비',
'경보 및 피난설비' : '경보 및 피난설비',
'장애인 전용 주차구역' : '장애인 전용 주차구역',
'객실 및 침실' : '객실 및 침실', 
'욕실' : '욕실',
'샤워실 및 탈의실' : '샤워실 및 탈의실',
'세면대' : '세면대',
'장애인용 화장실' : '장애인용 화장실',   
'남성용-장애인용대변기' :'장애인용 화장실',
'남성용-어린이용소변기' :'장애인용 화장실' ,
'남성용-장애인용소변기' : '장애인용 화장실',
'남성용-어린이용대변기' :'장애인용 화장실' , 
'여성용-어린이용대변기' : '장애인용 화장실', 
'남녀공용화장실' :'장애인용 화장실', 
'남성용-대변기' : '장애인용 화장실' , 
'여성용-대변기' :'장애인용 화장실',    
'여성용-장애인용대변기' : '장애인용 화장실',     
'남성용-소변기' :'장애인용 화장실', 
'접수대 및 작업대' : '접수대 및 작업대',
'장애인용 관람석' : '장애인용 관람석',
'점자블록': '점자블록', 
'장애인용 승강기': '장애인용 승강기',
'음료대' : '음료대',
'자동 판매기' : '자동 판매기',
'휠체어리프트': '장애인용 승강기',
'에스켈레이터':'장애인용 승강기',
'수평보행기':'장애인용 승강기',}

# %%
data['total_facility_available_name'] = data.facility_available_name.apply(lambda x : total_facility_available_name[x])

# %% [markdown]
# # 한글 명세

# %%
data['category'] = data.category.apply(lambda x : facility_name_ko[x])

# %%
data['large_range_category'] = large_split_data.category.apply(lambda x : facility_name_ko[x])

# %%
data.head()
# Out:
#   category        lat         lon place_address  place_id place_name  \
# 0      지하철  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 1      지하철  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 2      지하철  37.492317  127.118104     서울특별시 송파구         0       가락시장
# 3      지하철  37.480890  126.882574     서울특별시 금천구         1    가산디지털단지
# 4      지하철  37.480890  126.882574     서울특별시 금천구         1    가산디지털단지
#
#   facility_available_name facility_is_available  facility_id   Gu  \
# 0                장애인용 화장실                  이용가능       900000  송파구
# 1                장애인용 승강기                  이용가능       900001  송파구
# 2                  휠체어리프트                  이용가능       900002  송파구
# 3                  휠체어리프트                  이용가능       900003  금천구
# 4                장애인용 화장실                  이용가능       900004  금천구
#
#   total_facility_available_name large_range_category
# 0                      장애인용 화장실                  지하철
# 1                      장애인용 승강기                  지하철
# 2                      장애인용 승강기                  지하철
# 3                      장애인용 승강기                  지하철
# 4                      장애인용 화장실                  지하철

# %%
data.to_csv("total.csv")

# %%
data.drop_duplicates(subset=["total_facility_available_name", "place_name"] ,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34189 entries, 0 to 46522
# Data columns (total 12 columns):
# category                         34189 non-null object
# lat                              34189 non-null float64
# lon                              34189 non-null float64
# place_address                    34189 non-null object
# place_id                         34189 non-null int64
# place_name                       34189 non-null object
# facility_available_name          34189 non-null object
# facility_is_available            14443 non-null object
# facility_id                      34189 non-null int64
# Gu                               34181 non-null object
# total_facility_available_name    34189 non-null object
# large_range_category             34189 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.4+ MB

# %%
data = data[data.Gu != "수정구"]

# %%
data = data[data.Gu != "덕양구"]

# %%
data[data.facility_available_name.str.contains('화장실')]
# Out:
#       category        lat         lon           place_address  place_id  \
# 0          지하철  37.492317  127.118104               서울특별시 송파구         0
# 4          지하철  37.480890  126.882574               서울특별시 금천구         1
# 7          지하철  37.497942  127.027621               서울특별시 강남구         3
# 12         지하철  37.535940  127.132187               서울특별시 강동구         5
# 14         지하철  37.535144  127.094672               서울특별시 광진구         7
# 45203    공중화장실  37.608520  127.043013          서울특별시 성북구 상월곡동     30732
# 45239    공중화장실  37.592170  127.036688        서울특별시 성북구 종암동 30     30743
# 45259    공중화장실  37.610481  127.019438    서울특별시 성북구 길음동 1281-7     30749
# 45326    공중화장실  37.577942  127.022784     서울특별시 성북구 보문동7가 138     30771
# 45342    공중화장실  37.580368  127.022787   서울특별시 성북구 보문동7가 108-1     30779
# 45357    공중화장실  37.578684  127.022613     서울특별시 성북구 보문동7가 118     30784
# 45371    공중화장실  37.593603  127.015737    서울특별시 성북구 동소문동6가 146     30790
# 45419    공중화장실  37.584974  127.031059  서울특별시 성북구 안암동5가 86-121     30809
# 45450    공중화장실  37.613371  127.006986     서울특별시 성북구 정릉동 293-6     30821
# 45461    공중화장실  37.603718  127.043044     서울특별시 성북구 하월곡동 17-1     30825
# 45919    공중화장실  37.323026  126.522634     서울특별시 양천구 목2동 산23-5     30938
#
#                     place_name facility_available_name facility_is_available  \
# 0                         가락시장                장애인용 화장실                  이용가능
# 4                      가산디지털단지                장애인용 화장실                  이용가능
# 7                           강남                장애인용 화장실                  이용가능
# 12                          강동                장애인용 화장실                  이용가능
# 14                          강변                장애인용 화장실                  이용가능
# 17                          개농                장애인용 화장실                  이용가능
# 19                         개화산                장애인용 화장실                  이용가능
# 22                          거여                장애인용 화장실                  이용가능
# 27                        건대입구                장애인용 화장실                  이용가능
# 29                          고덕                장애인용 화장실                  이용가능
# 32                         고려대                장애인용 화장실                  이용가능
# 35                       고속터미널                장애인용 화장실                  이용가능
# 38                          공덕                장애인용 화장실                  이용가능
# 42                          공릉                장애인용 화장실                  이용가능
# 44                         광나루                장애인용 화장실                  이용가능
# 46                       광명사거리                장애인용 화장실                  이용가능
# 49                         광화문                장애인용 화장실                  이용가능
# 54                         광흥창                장애인용 화장실                  이용가능
# 56                          교대                장애인용 화장실                  이용가능
# 59                     구로디지털단지                장애인용 화장실                  이용가능
# 61                          구산                장애인용 화장실                  이용가능
# 67                          구의                장애인용 화장실                  이용가능
# 68                         구파발                장애인용 화장실                  이용가능
# 71                          군자                장애인용 화장실                  이용가능
# 73                        굽은다리                장애인용 화장실                  이용가능
# 77                          금호                장애인용 화장실                  이용가능
# 80                          길동                장애인용 화장실                  이용가능
# 82                          길음                장애인용 화장실                  이용가능
# 83                        김포공항                장애인용 화장실                  이용가능
# 86                         까치산                장애인용 화장실                  이용가능
# ...                        ...                     ...                   ...
# 39754              행당어린이공원 화장실                 남녀공용화장실                   NaN
# 40352             방이공원 화장실 화장실                 남녀공용화장실                   NaN
# 40395       가락공원1(관리동) 화장실 화장실                 남녀공용화장실                   NaN
# 40412      가락공원2 (족구장) 화장실 화장실                 남녀공용화장실                   NaN
# 41124              아이티벤처타워 화장실                 남녀공용화장실                   NaN
# 41141               파크인수빌딩 화장실                 남녀공용화장실                   NaN
# 41157               향군타워B동 화장실                 남녀공용화장실                   NaN
# 41168                문산부인과 화장실                 남녀공용화장실                   NaN
# 41657                진양주유소 화장실                 남녀공용화장실                   NaN
# 40352       300366  송파구                      장애인용 화장실                  화장실
# 40395       300379  송파구                      장애인용 화장실                  화장실
# 40412       300383  송파구                      장애인용 화장실                  화장실
# 41124       300608  송파구                      장애인용 화장실                  화장실
# 41141       300611  송파구                      장애인용 화장실                  화장실
# 41157       300614  송파구                      장애인용 화장실                  화장실
# 41168       300617  송파구                      장애인용 화장실                  화장실
# 41657       300757  송파구                      장애인용 화장실                  화장실
# 42180       300937  송파구                      장애인용 화장실                  화장실
# 42513       301056  송파구                      장애인용 화장실                  화장실
# 43477       301362  금천구                      장애인용 화장실                  화장실
# 43517       301377  금천구                      장애인용 화장실                  화장실
# 44183       301794  강서구                      장애인용 화장실                  화장실
# 44851       302486  은평구                      장애인용 화장실                  화장실
# 44884       302521  은평구                      장애인용 화장실                  화장실
# 44918       302552  은평구                      장애인용 화장실                  화장실
# 45011       302646  관악구                      장애인용 화장실                  화장실
# 45091       302728  서초구                      장애인용 화장실                  화장실
# 45203       302841  성북구                      장애인용 화장실                  화장실
# 45239       302881  성북구                      장애인용 화장실                  화장실
# 45259       302904  성북구                      장애인용 화장실                  화장실
# 45326       302967  성북구                      장애인용 화장실                  화장실
# 45342       302988  성북구                      장애인용 화장실                  화장실
# 45357       303002  성북구                      장애인용 화장실                  화장실
# 45371       303015  성북구                      장애인용 화장실                  화장실
# 45419       303064  성북구                      장애인용 화장실                  화장실
# 45450       303095  성북구                      장애인용 화장실                  화장실
# 45461       303106  성북구                      장애인용 화장실                  화장실
# 45919       303572  양천구                      장애인용 화장실                  화장실
#
# [2178 rows x 12 columns]

# %% [markdown]
# # 최종 DB에 저장하기위한 CSV CREATE

# %%
facility = data[['facility_id', 'place_id',  'total_facility_available_name' , 'place_name', 'facility_is_available' ]]

# %%
facility.rename(columns={'total_facility_available_name' : 'facility_available_name'}, inplace=True)

# %%
facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34175 entries, 0 to 46522
# Data columns (total 5 columns):
# facility_id                34175 non-null int64
# place_id                   34175 non-null int64
# facility_available_name    34175 non-null object
# place_name                 34175 non-null object
# facility_is_available      14429 non-null object
# dtypes: int64(2), object(3)
# memory usage: 1.6+ MB

# %%
facility.to_csv("facility.csv")

# %%
place = data[['place_id', 'place_name', 'lat', 'lon', 'place_address', 'large_range_category']]

# %%
place.rename(columns={"large_range_category" : "category", "lon" : "lng"}, inplace=True)

# %%
place =category_place_sum(place, "화장실", "공중화장실", )

# %%
place.drop_duplicates(subset=["place_id"],inplace=True)

# %%
place.drop_duplicates(subset=["place_name"],inplace=True)

# %%
place.to_csv('place.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34175 entries, 0 to 46522
# Data columns (total 12 columns):
# category                         34175 non-null object
# lat                              34175 non-null float64
# lon                              34175 non-null float64
# place_address                    34175 non-null object
# place_id                         34175 non-null int64
# place_name                       34175 non-null object
# facility_available_name          34175 non-null object
# facility_is_available            14429 non-null object
# facility_id                      34175 non-null int64
# Gu                               34167 non-null object
# total_facility_available_name    34175 non-null object
# large_range_category             34175 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# # 분석용 csv CREATE

# %%
data.to_csv("for_eda.csv")
