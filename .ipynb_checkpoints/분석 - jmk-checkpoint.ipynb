# %% [markdown]
# # 1-1 category별로 여러 편의시설 설치된 곳을 찾기

# %%
import pandas as pd

# %%
import pdvega

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
from matplotlib import font_manager, rc
path = 'c:/windows/fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
test = pd.read_csv('test.csv')

# %%
graph1 = test.groupby('category').facility_available_name.count()

# %%
graph1.vgplot.bar(width = 500, height=500,interactive=False)
# Out:
# <div class="vega-embed" id="30d6d265-868a-4664-8957-f96d6b8f9563"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %% [markdown]
# # category별로 편의시설 유형 파악

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
test.category.unique()
# Out:
# array(['subway', 'movie/concerthall', 'shopping/mart', 'publicparking',
#        'publictoilet', 'hospital', 'delete', 'community service center',
#        'police station', 'post office', 'health center', 'bank', 'hotel',
#        'daycare center', 'education/job', 'elementary school',
#        'high school', 'junior high school', 'university',
#        'special-education school', 'library', 'beauty/hair', 'other',
#        'restaurant', nan, 'apartment subsidiary facility',
#        'exhibition center', 'convenience store/bakery', 'kindergarten',
#        'welfare/senior', 'welfare/etc', 'city park', 'welfare/disabled',
#        'meeting hall', 'training facility/rural', 'welfare/child',
#        'church', 'gym', 'nature park', 'toilet/public',
#        'training facility/urban', 'college', 'toilet/open',
#        'toilet/small'], dtype=object)

# %%
len(test.category.unique())
# Out:
# 44

# %%
test[test.category=='subway'].groupby('facility_available_name').facility_id.count()
# Out:
# facility_available_name
# 계단핸드레일      2
# 수평보행기       3
# 에스켈레이터    132
# 엘리베이터     211
# 화장실       213
# 휠체어리프트     77
# Name: facility_id, dtype: int64

# %%
graph2 = []
for result in test.category.unique():
    graph2.append(test[test.category ==  result].groupby('facility_available_name').facility_id.count())

# %%
for i, result in enumerate(test.category.unique()):
    print(result)
    graph2[i].vgplot.bar( width = 300, height=300,interactive = False)
# Out:
# subway
# <div class="vega-embed" id="f36a6f7b-d80e-4c0e-9ecb-4f05cc93b549"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# movie/concerthall
# <div class="vega-embed" id="33d6c90f-6b3b-46c8-b8b6-73843db11ebb"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# shopping/mart
# <div class="vega-embed" id="0e30ca7c-dfa6-47bd-8196-36f7013d68a8"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# publicparking
# <div class="vega-embed" id="9484a18c-2222-4f55-b40d-302876fe0fcb"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# publictoilet
# <div class="vega-embed" id="78fac7e6-c5b0-48af-89f6-044950940a71"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# hospital
# <div class="vega-embed" id="442f7eb1-cfef-448b-a1db-4f34ad1c4fd4"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# delete
# <div class="vega-embed" id="538d049d-c71a-43da-99f0-c750b9e7175e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# community service center
# <div class="vega-embed" id="6b10d675-a9dd-49bc-80d5-6c2ea023dd8a"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# police station
# <div class="vega-embed" id="650f2f6e-3f51-4c41-a88c-c1999a7b2c0c"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# post office
# <div class="vega-embed" id="e5a0f304-5536-4483-a2b0-27190f41ec75"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# health center
# <div class="vega-embed" id="59a48189-767a-4477-b5d3-d43aa18e0aa0"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# bank
# <div class="vega-embed" id="67c287a0-d994-40e6-862e-add9e68ee298"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# hotel
# <div class="vega-embed" id="88563d60-477d-4389-a0b6-488cdef5e4d3"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# daycare center
# <div class="vega-embed" id="0a2e7a52-8865-4cee-86f2-4e2886aa669e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# education/job
# <div class="vega-embed" id="6114518b-3437-48c9-bfc7-eff373c5a6f6"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# elementary school
# <div class="vega-embed" id="6ee35ede-7097-4af6-98a7-2199e8958f73"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# high school
# <div class="vega-embed" id="d96b16d4-3e74-40a0-a312-e2832db6bfda"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# junior high school
# <div class="vega-embed" id="143fac57-f1f1-4278-86c0-948062bec3c6"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# university
# <div class="vega-embed" id="d9837c35-39d2-4fb8-abaf-c515cc63a6e2"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# special-education school
# <div class="vega-embed" id="d7de088a-1579-4490-a337-b963f4652c49"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# library
# <div class="vega-embed" id="20ac4e59-17e3-4986-8d98-42f5a79c3abb"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# beauty/hair
# <div class="vega-embed" id="58d8a596-f3a4-44fb-a2e3-25a0afee9c9e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# other
# <div class="vega-embed" id="4049733f-6406-4fd6-93fc-e9c068d99d7d"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# restaurant
# <div class="vega-embed" id="558be389-02eb-4765-ae7e-3f9b597cd431"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# nan
# C:\Users\user\Anaconda3\lib\site-packages\pdvega\_utils.py:43: UserWarning: I don't know how to infer vegalite type from 'empty'.  Defaulting to nominal.
#   "Defaulting to nominal.".format(typ))
# <div class="vega-embed" id="fc081563-9d12-482e-a31a-d51e21bf8691"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# apartment subsidiary facility
# <div class="vega-embed" id="c59bec87-4a37-4e6a-a72b-ba18ecd78e68"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# exhibition center
# <div class="vega-embed" id="86794eca-cbd1-4803-9a8e-bc7c250ed6cb"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# convenience store/bakery
# <div class="vega-embed" id="152ac7f2-0ef0-477b-96e4-420b1ee15a94"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# kindergarten
# <div class="vega-embed" id="881a4091-ea11-40ef-a8f0-8530ff13a47d"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/senior
# <div class="vega-embed" id="6016024c-6f84-4dd8-8804-feb928a1ea26"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/etc
# <div class="vega-embed" id="0376cee0-12fa-49ee-93b4-80a2d8937bd2"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# city park
# <div class="vega-embed" id="f3ae64b7-67f2-4a4d-b0dc-a7bf405ce678"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/disabled
# <div class="vega-embed" id="e76a6f8e-8112-4c30-b160-2b0db426d456"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# meeting hall
# <div class="vega-embed" id="274f8efe-0dd8-4072-b852-39210312ac88"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# training facility/rural
# <div class="vega-embed" id="217d0100-7177-4555-958c-2e12b59c66fa"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# welfare/child
# <div class="vega-embed" id="3b86a358-b7a5-4587-b19a-8fd71f399361"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# church
# <div class="vega-embed" id="38cf6bf1-11a4-4466-946e-4f0d91d1a0ce"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# gym
# <div class="vega-embed" id="576e7363-dd47-4215-a6f3-61e83749803f"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# nature park
# <div class="vega-embed" id="826c7d12-35c6-4e13-81b4-354af88a738a"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/public
# <div class="vega-embed" id="4a76ae7c-3b4a-4e54-aa89-6da04e976961"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# training facility/urban
# <div class="vega-embed" id="86cf606d-490a-4dac-86ed-7fb23433d35d"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# college
# <div class="vega-embed" id="a1ed7b11-fb51-4dd2-85a5-c9d3b459cfb9"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/open
# <div class="vega-embed" id="594a69a0-642c-4006-94f8-8936e05e5cb2"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
# toilet/small
# <div class="vega-embed" id="38d460f9-80a5-4fd6-aea7-0174260b80e4"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
test.place_address.isna().sum()
# Out:
# 5779

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
ttest = test.copy()

# %%
ttest.index.isna().sum()
# Out:
# 0

# %%
ttest.facility_id.isna().sum()
# Out:
# 5141

# %%
ttest.place_name.isna().sum()
# Out:
# 5141

# %%
ttest.place_id.isna().sum()
# Out:
# 5141

# %%
ttest.isna().any()
# Out:
# Unnamed: 0                 False
# index                       True
# category                    True
# lat                         True
# lon                         True
# place_address               True
# place_id                    True
# place_name                  True
# facility_available_name     True
# facility_is_available       True
# facility_id                 True
# dtype: bool

# %%
ttest.place_address
# Out:
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
#                  ...
# 60826     서울특별시 서초구 방배동 산75-4
# 60827     서울특별시 서초구 방배동 산75-4
# 60828     서울특별시 서초구 반포동 115-4
# 60829     서울특별시 서초구 반포동 115-4
# 60830     서울특별시 서초구 반포동 115-4
# 60831     서울특별시 서초구 반포동 115-4
# 60832     서울특별시 서초구 반포동 115-4
# 60833       서울특별시 서초구 방배동 599
# 60834       서울특별시 서초구 방배동 599
# 60835       서울특별시 서초구 방배동 599
# 60836     서울특별시 서초구 양재동 126-1
# 60837     서울특별시 서초구 양재동 126-1
# 60838     서울특별시 서초구 양재동 126-1
# 60839    서울특별시 서초구 양재동 261-23
# 60840    서울특별시 서초구 양재동 261-23
# 60841    서울특별시 서초구 양재동 261-23
# 60842    서울특별시 서초구 양재동 261-23
# 60843    서울특별시 서초구 양재동 261-23
# 60844     서울특별시 서초구 우면동 143-6
# 60845     서울특별시 서초구 우면동 143-6
# 60846     서울특별시 서초구 우면동 143-6
# 60847     서울특별시 서초구 우면동 143-6
# 60848     서울특별시 서초구 우면동 143-6
# 60849    서울특별시 성동구 사근동 102-28
# 60850    서울특별시 성동구 사근동 102-28
# 60851    서울특별시 성동구 사근동 102-28
# 60852    서울특별시 성동구 사근동 102-28
# 60853       서울특별시 성동구 마장동 811
# 60854       서울특별시 성동구 마장동 811
# 60855       서울특별시 성동구 마장동 811
# Name: place_address, Length: 60856, dtype: object

# %%
import numpy as np

# %%
ttest.head()
# Out:
#    Unnamed: 0  index category        lat         lon place_address  place_id  \
# 0           0    0.0   subway  37.492317  127.118104           NaN       0.0
# 1           1    1.0   subway  37.492317  127.118104           NaN       0.0
# 2           2    2.0   subway  37.492317  127.118104           NaN       0.0
# 3           3    3.0   subway  37.480890  126.882574           NaN       1.0
# 4           4    4.0   subway  37.480890  126.882574           NaN       1.0
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능     900000.0
# 1       가락시장                   엘리베이터                  이용가능     900001.0
# 2       가락시장                  휠체어리프트                  이용가능     900002.0
# 3    가산디지털단지                  에스켈레이터                  이용가능     900003.0
# 4    가산디지털단지                     화장실                  이용가능     900004.0

# %%
ttest[['place_address','place_']].dropna()
# Out:
#                                 place_address
# 638                        서울특별시 종로구 동숭동 1-37
# 639                        서울특별시 종로구 동숭동 1-37
# 640                      서울특별시 강남구 신사동  568-2
# 641                      서울특별시 강남구 신사동  568-2
# 642                      서울특별시 강남구 신사동  568-2
# 643                      서울특별시 강남구 신사동  568-2
# 644                      서울특별시 강남구 신사동  568-2
# 645                        서울특별시 종로구 관철동 33-1
# 646                        서울특별시 종로구 관철동 33-1
# 647                        서울특별시 종로구 관철동 33-1
# 648                        서울특별시 종로구 관철동 33-1
# 649                        서울특별시 종로구 관철동 33-1
# 650           서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 651           서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 652           서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 653           서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 654           서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 655                서울특별시 중구 명동2가 83-5 눈스퀘어 8층
# 656                서울특별시 중구 명동2가 83-5 눈스퀘어 8층
# 657                        서울특별시 마포구 월드컵로 240
# 658                        서울특별시 마포구 월드컵로 240
# 659    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 660    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 661    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 662    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 663    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 664    서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 665                          서울특별시 강동구 성내로 48
# 666                          서울특별시 강동구 성내로 48
# 667                          서울특별시 강동구 성내로 48
# ...                                       ...
# 60826                     서울특별시 서초구 방배동 산75-4
# 60827                     서울특별시 서초구 방배동 산75-4
# 60828                     서울특별시 서초구 반포동 115-4
# 60829                     서울특별시 서초구 반포동 115-4
# 60830                     서울특별시 서초구 반포동 115-4
# 60831                     서울특별시 서초구 반포동 115-4
# 60832                     서울특별시 서초구 반포동 115-4
# 60833                       서울특별시 서초구 방배동 599
# 60834                       서울특별시 서초구 방배동 599
# 60835                       서울특별시 서초구 방배동 599
# 60836                     서울특별시 서초구 양재동 126-1
# 60837                     서울특별시 서초구 양재동 126-1
# 60838                     서울특별시 서초구 양재동 126-1
# 60839                    서울특별시 서초구 양재동 261-23
# 60840                    서울특별시 서초구 양재동 261-23
# 60841                    서울특별시 서초구 양재동 261-23
# 60842                    서울특별시 서초구 양재동 261-23
# 60843                    서울특별시 서초구 양재동 261-23
# 60844                     서울특별시 서초구 우면동 143-6
# 60845                     서울특별시 서초구 우면동 143-6
# 60846                     서울특별시 서초구 우면동 143-6
# 60847                     서울특별시 서초구 우면동 143-6
# 60848                     서울특별시 서초구 우면동 143-6
# 60849                    서울특별시 성동구 사근동 102-28
# 60850                    서울특별시 성동구 사근동 102-28
# 60851                    서울특별시 성동구 사근동 102-28
# 60852                    서울특별시 성동구 사근동 102-28
# 60853                       서울특별시 성동구 마장동 811
# 60854                       서울특별시 성동구 마장동 811
# 60855                       서울특별시 성동구 마장동 811
#
# [55077 rows x 1 columns]

# %%
ttest.place_address.dropna()
# Out:
# 638                          서울특별시 종로구 동숭동 1-37
# 639                          서울특별시 종로구 동숭동 1-37
# 640                        서울특별시 강남구 신사동  568-2
# 641                        서울특별시 강남구 신사동  568-2
# 642                        서울특별시 강남구 신사동  568-2
# 643                        서울특별시 강남구 신사동  568-2
# 644                        서울특별시 강남구 신사동  568-2
# 645                          서울특별시 종로구 관철동 33-1
# 646                          서울특별시 종로구 관철동 33-1
# 647                          서울특별시 종로구 관철동 33-1
# 648                          서울특별시 종로구 관철동 33-1
# 649                          서울특별시 종로구 관철동 33-1
# 650             서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 651             서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 652             서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 653             서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 654             서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 655                  서울특별시 중구 명동2가 83-5 눈스퀘어 8층
# 656                  서울특별시 중구 명동2가 83-5 눈스퀘어 8층
# 657                          서울특별시 마포구 월드컵로 240
# 658                          서울특별시 마포구 월드컵로 240
# 659      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 660      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 661      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 662      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 663      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 664      서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 665                            서울특별시 강동구 성내로 48
# 666                            서울특별시 강동구 성내로 48
# 667                            서울특별시 강동구 성내로 48
#                           ...
# 60826                       서울특별시 서초구 방배동 산75-4
# 60827                       서울특별시 서초구 방배동 산75-4
# 60828                       서울특별시 서초구 반포동 115-4
# 60829                       서울특별시 서초구 반포동 115-4
# 60830                       서울특별시 서초구 반포동 115-4
# 60831                       서울특별시 서초구 반포동 115-4
# 60832                       서울특별시 서초구 반포동 115-4
# 60833                         서울특별시 서초구 방배동 599
# 60834                         서울특별시 서초구 방배동 599
# 60835                         서울특별시 서초구 방배동 599
# 60836                       서울특별시 서초구 양재동 126-1
# 60837                       서울특별시 서초구 양재동 126-1
# 60838                       서울특별시 서초구 양재동 126-1
# 60839                      서울특별시 서초구 양재동 261-23
# 60840                      서울특별시 서초구 양재동 261-23
# 60841                      서울특별시 서초구 양재동 261-23
# 60842                      서울특별시 서초구 양재동 261-23
# 60843                      서울특별시 서초구 양재동 261-23
# 60844                       서울특별시 서초구 우면동 143-6
# 60845                       서울특별시 서초구 우면동 143-6
# 60846                       서울특별시 서초구 우면동 143-6
# 60847                       서울특별시 서초구 우면동 143-6
# 60848                       서울특별시 서초구 우면동 143-6
# 60849                      서울특별시 성동구 사근동 102-28
# 60850                      서울특별시 성동구 사근동 102-28
# 60851                      서울특별시 성동구 사근동 102-28
# 60852                      서울특별시 성동구 사근동 102-28
# 60853                         서울특별시 성동구 마장동 811
# 60854                         서울특별시 성동구 마장동 811
# 60855                         서울특별시 성동구 마장동 811
# Name: place_address, Length: 55077, dtype: object

# %%
ttest[ttest.place_address==np.nan]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, index, category, lat, lon, place_address, place_id, place_name, facility_available_name, facility_is_available, facility_id]
# Index: []

# %%
ttest.head()
# Out:
#    Unnamed: 0  index category        lat         lon place_address  place_id  \
# 0           0    0.0   subway  37.492317  127.118104           NaN       0.0
# 1           1    1.0   subway  37.492317  127.118104           NaN       0.0
# 2           2    2.0   subway  37.492317  127.118104           NaN       0.0
# 3           3    3.0   subway  37.480890  126.882574           NaN       1.0
# 4           4    4.0   subway  37.480890  126.882574           NaN       1.0
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능     900000.0
# 1       가락시장                   엘리베이터                  이용가능     900001.0
# 2       가락시장                  휠체어리프트                  이용가능     900002.0
# 3    가산디지털단지                  에스켈레이터                  이용가능     900003.0
# 4    가산디지털단지                     화장실                  이용가능     900004.0

# %%
ttest.place_address.isna().sum()
# Out:
# 0

# %%
ff = ttest[ttest['place_address'].isna()]
# Out:
#   File "<ipython-input-109-8355ee7f3f9c>", line 1
#     ff = ttest[!ttest['place_address'].isna()]
#                ^
# SyntaxError: invalid syntax

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
ttest.place_address = ff

# %%
ttest.head()
# Out:
#    Unnamed: 0  index category        lat         lon place_address  place_id  \
# 0           0    0.0   subway  37.492317  127.118104           NaN       0.0
# 1           1    1.0   subway  37.492317  127.118104           NaN       0.0
# 2           2    2.0   subway  37.492317  127.118104           NaN       0.0
# 3           3    3.0   subway  37.480890  126.882574           NaN       1.0
# 4           4    4.0   subway  37.480890  126.882574           NaN       1.0
#
#   place_name facility_available_name facility_is_available  facility_id
# 0       가락시장                     화장실                  이용가능     900000.0
# 1       가락시장                   엘리베이터                  이용가능     900001.0
# 2       가락시장                  휠체어리프트                  이용가능     900002.0
# 3    가산디지털단지                  에스켈레이터                  이용가능     900003.0
# 4    가산디지털단지                     화장실                  이용가능     900004.0

# %%
ttest.place_address.dropna(inplace=True)

# %%
ttest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60856 entries, 0 to 60855
# Data columns (total 11 columns):
# Unnamed: 0                 60856 non-null int64
# index                      55715 non-null float64
# category                   55715 non-null object
# lat                        55715 non-null float64
# lon                        55715 non-null float64
# place_address              55077 non-null object
# place_id                   55715 non-null float64
# place_name                 55715 non-null object
# facility_available_name    55715 non-null object
# facility_is_available      16151 non-null object
# facility_id                55715 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
ttest.place_address.isna().sum()
# Out:
# 0

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=graph2[0])

p = figure( plot_height=350, toolbar_location=None, title="Fruit Counts")
# p.vbar(x='fruits', top='counts', width=0.9, source=graph2[0], legend="fruits",
#        line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7c5c79f479dd> in <module>()
#      10 counts = [5, 3, 4, 2, 4, 6]
#      11
# ---> 12 source = ColumnDataSource(data=graph2[0])
#      13
#      14 p = figure( plot_height=350, toolbar_location=None, title="Fruit Counts")
#
# ~\Anaconda3\lib\site-packages\bokeh\models\sources.py in __init__(self, *args, **kw)
#     127                 raw_data = self._data_from_groupby(raw_data)
#     128             else:
# --> 129                 raise ValueError("expected a dict or pandas.DataFrame, got %s" % raw_data)
#     130         super(ColumnDataSource, self).__init__(**kw)
#     131         self.data.update(raw_data)
#
# ValueError: expected a dict or pandas.DataFrame, got facility_available_name
# 계단핸드레일      2
# 수평보행기       3
# 에스켈레이터    132
# 엘리베이터     211
# 화장실       213
# 휠체어리프트     77
# Name: facility_id, dtype: int64

# %%
source
# Out:
# ColumnDataSource(id='4410a533-4c00-4eed-9031-260f144e095f', ...)
