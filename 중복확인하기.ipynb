# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('disabled_facilities.db')

# %% [markdown]
# cur = conn.cursor()
#
# result = cur.execute("select * from facilities")

# %%
hj = pd.read_sql_query("SELECT * FROM facilities", conn)  #19291

# %%
hj_another_tb = pd.read_sql_query("SELECT * FROM facilities_detail", conn)  #19291

# %%
hj.head()
# Out:
#     id    faclInfId    faclLat     faclLng         faclNm faclTyCd  \
# 0  935  20140610062  37.562726  127.032570    (구)왕십리클리닉빌딩   UC0K02
# 1  937  20140762484  37.573937  126.983187  (재)대한불교계종유지재단   UC0A01
# 2  938  20140512111  37.485282  126.931355    (주)관전인베스트먼트   UC0L02
# 3  939  20140758598  37.490768  126.982048       (주)대광메디텍   UC0A01
# 4  941  20140609927  37.544932  126.910696       (주)동아일보사   UC0K02
#
#                      lcMnad     wfcltId  \
# 0        서울특별시 성동구 왕십리로 333  0000073296
# 1         서울특별시 종로구 우정국로 56  0000000002
# 2  서울특별시 관악구 신림로64길29 (신림동)  0000142761
# 3       서울특별시 동작구 동작대로35길 5  0000000229
# 4           서울특별시 마포구 토정로 1  0000073146
#
#                                             evalInfo
# 0  계단 또는 승강설비,대변기,장애인전용주차구역,주출입구 높이차이 제거,주출입구 접근로...
# 1                       주출입구 높이차이 제거,주출입구 접근로,출입구(문)
# 2  객실 및 침실,계단 또는 승강설비,대변기,복도,세면대,소변기,일반사항,장애인전용주차...
# 3                       주출입구 높이차이 제거,주출입구 접근로,출입구(문)
# ...

# %%
hj_another_tb.head(20)
# Out:
#     id     facility_available_name  facility_id
# 0    1      계단 또는 승강설비_(구)왕십리클리닉빌딩          935
# 1    2             대변기_(구)왕십리클리닉빌딩          935
# 2    3       장애인전용주차구역_(구)왕십리클리닉빌딩          935
# 3    4    주출입구 높이차이 제거_(구)왕십리클리닉빌딩          935
# 4    5        주출입구 접근로_(구)왕십리클리닉빌딩          935
# 5    6          출입구(문)_(구)왕십리클리닉빌딩          935
# 6    7         해당시설 층수_(구)왕십리클리닉빌딩          935
# 7    8  주출입구 높이차이 제거_(재)대한불교계종유지재단          937
# 8    9      주출입구 접근로_(재)대한불교계종유지재단          937
# 9   10        출입구(문)_(재)대한불교계종유지재단          937
# 10  11         객실 및 침실_(주)관전인베스트먼트          938
# 11  12      계단 또는 승강설비_(주)관전인베스트먼트          938
# 12  13             대변기_(주)관전인베스트먼트          938
# 13  14              복도_(주)관전인베스트먼트          938
# 14  15             세면대_(주)관전인베스트먼트          938
# 15  16             소변기_(주)관전인베스트먼트          938
# 16  17            일반사항_(주)관전인베스트먼트          938
# 17  18       장애인전용주차구역_(주)관전인베스트먼트          938
# 18  19    주출입구 높이차이 제거_(주)관전인베스트먼트          938
# ...

# %%
hj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10431 entries, 0 to 10430
# Data columns (total 9 columns):
# id           10431 non-null int64
# faclInfId    10431 non-null int64
# faclLat      10431 non-null float64
# faclLng      10431 non-null float64
# faclNm       10431 non-null object
# faclTyCd     10431 non-null object
# lcMnad       10431 non-null object
# wfcltId      10431 non-null object
# evalInfo     10431 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 733.5+ KB

# %%
hj.describe()
# Out:
#                  id     faclInfId       faclLat       faclLng
# count  10431.000000  1.043100e+04  10431.000000  10431.000000
# mean   10159.775093  2.011368e+10     37.545611    126.991178
# std     5278.470019  7.374023e+08      0.051872      0.084824
# min      935.000000  3.906000e+03     37.434986    126.795628
# 25%     5830.500000  2.014061e+10     37.502745    126.920837
# 50%    10222.000000  2.014075e+10     37.541449    127.008870
# 75%    14609.500000  2.014076e+10     37.575051    127.054494
# max    19291.000000  2.014076e+10     37.694840    127.178321

# %%
hj.rename(columns = {'faclLat':'lat','faclLng':'lon','faclTyCd':'category'}, inplace = True)
hj.rename(columns = {'faclNm' : 'place_name','lcMnad':'place_address','id':'place_id'}, inplace = True)

# %%
hj.columns
# Out:
# Index(['place_id', 'faclInfId', 'lat', 'lon', 'place_name', 'category',
#        'place_address', 'wfcltId', 'evalInfo'],
#       dtype='object')

# %%
hj.drop_duplicates(subset=['lat','lon'],inplace=True)

# %%
hj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9548 entries, 0 to 10430
# Data columns (total 9 columns):
# place_id         9548 non-null int64
# faclInfId        9548 non-null int64
# lat              9548 non-null float64
# lon              9548 non-null float64
# place_name       9548 non-null object
# category         9548 non-null object
# place_address    9548 non-null object
# wfcltId          9548 non-null object
# evalInfo         9548 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 745.9+ KB

# %%
# hj 데이터에 place_name - 이거인것들 다빼야함.

# %%
hj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9548 entries, 0 to 10430
# Data columns (total 9 columns):
# place_id         9548 non-null int64
# faclInfId        9548 non-null int64
# lat              9548 non-null float64
# lon              9548 non-null float64
# place_name       9548 non-null object
# category         9548 non-null object
# place_address    9548 non-null object
# wfcltId          9548 non-null object
# evalInfo         9548 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 745.9+ KB

# %%
hj.columns
# Out:
# Index(['place_id', 'faclInfId', 'lat', 'lon', 'place_name', 'category',
#        'place_address', 'wfcltId', 'evalInfo'],
#       dtype='object')

# %%
hjs = hj[['place_id','place_name','place_address','lat','lon','category']]

# %%
hjs.head()
# Out:
#    place_id     place_name             place_address        lat         lon  \
# 0       935    (구)왕십리클리닉빌딩        서울특별시 성동구 왕십리로 333  37.562726  127.032570
# 1       937  (재)대한불교계종유지재단         서울특별시 종로구 우정국로 56  37.573937  126.983187
# 2       938    (주)관전인베스트먼트  서울특별시 관악구 신림로64길29 (신림동)  37.485282  126.931355
# 3       939       (주)대광메디텍       서울특별시 동작구 동작대로35길 5  37.490768  126.982048
# 4       941       (주)동아일보사           서울특별시 마포구 토정로 1  37.544932  126.910696
#
#   category
# 0   UC0K02
# 1   UC0A01
# 2   UC0L02
# 3   UC0A01
# 4   UC0K02

# %%
#df[['lat','lon','faclNm','evalInfo']][(df.lon>126.95300)&(df.lon<126.95330)]

# %% [markdown]
# -----

# %% [markdown]
# # 영준이 데이터

# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
main_place =pd.read_csv("yj_main_dish_place/main_place.csv",dtype={'lat':str,'lon':str})
main_place[main_place.place_name.str.contains('문일')]
# Out:
#       Unnamed: 0 place_name         place_address         lat          lon  \
# 2391         598     문일고등학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
# 2392         599      문일중학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
#
#                  category  place_id
# 2391  education/Childcare     12391
# 2392  education/Childcare     12392

# %%
main_place.tail()
# Out:
#       Unnamed: 0 place_name            place_address         lat          lon  \
# 4851         904    휘경문화웨딩원       서울특별시 동대문구 망우로 123  37.5917142  127.0666134
# 4852         905   흑석제일감리교회     서울특별시 동작구 서달로10나길 21  37.5029945  126.9627396
# 4853         906     흑석체육센터         서울특별시 동작구 현충로 73  37.5100514  126.9634913
# 4854         907   흥원사가양동법당  서울특별시 강서구 양천로49길  56-12  37.5719909  126.8404808
# 4855         908       흥황교회       서울특별시 구로구 천왕로1길 33  37.4817169  126.8361392
#
#      category  place_id
# 4851    other     14851
# 4852    other     14852
# 4853    other     14853
# 4854    other     14854
# 4855    other     14855

# %%
main_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4856 entries, 0 to 4855
# Data columns (total 7 columns):
# Unnamed: 0       4856 non-null int64
# place_name       4856 non-null object
# place_address    4856 non-null object
# lat              4739 non-null object
# lon              4739 non-null object
# category         4856 non-null object
# place_id         4856 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 265.6+ KB

# %%
d = main_place.lat.str.contains("37.4491498",na=False)

# %%
main_place[d]
# Out:
#       Unnamed: 0 place_name         place_address         lat          lon  \
# 2391         598     문일고등학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
# 2392         599      문일중학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
#
#                  category  place_id
# 2391  education/Childcare     12391
# 2392  education/Childcare     12392

# %%
main_place = main_place[['place_id','place_name','place_address','lat','lon','category']]

# %%
main_place.columns
# Out:
# Index(['place_id', 'place_name', 'place_address', 'lat', 'lon', 'category'], dtype='object')

# %%
# tt = main_place[["lat","lon"]].duplicated(keep=False)
# yj_joongbok =main_place[tt] # 영준씨 중복된 데이터
# yj_joongbok.info()

# %%
#yj_joongbok[yj_joongbok.lat.isna()].head(10)

# %%
#yj_joongbok.sort_values(["lat",'lon'],).head(10)

# %%
main_place[main_place.place_name.str.contains('^문일')]
# Out:
#       place_id place_name         place_address         lat          lon  \
# 2391     12391     문일고등학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
# 2392     12392      문일중학교  서울특별시 금천구 시흥대로47길 45  37.4491498  126.8990574
#
#                  category
# 2391  education/Childcare
# 2392  education/Childcare

# %%
main_place.dropna(inplace=True) # drop NA

# %% [markdown]
# ##### yjs 에 있던 lat ,lon 이 Nan 이었던 데이터들 모두 사라졌다. drop NA

# %%
main_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4739 entries, 0 to 4855
# Data columns (total 6 columns):
# place_id         4739 non-null int64
# place_name       4739 non-null object
# place_address    4739 non-null object
# lat              4739 non-null object
# lon              4739 non-null object
# category         4739 non-null object
# dtypes: int64(1), object(5)
# memory usage: 259.2+ KB

# %%
main_place.drop_duplicates(subset=['lat','lon'],inplace=True) # lat , lon 의 중복제거

# %%
main_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4446 entries, 0 to 4855
# Data columns (total 6 columns):
# place_id         4446 non-null int64
# place_name       4446 non-null object
# place_address    4446 non-null object
# lat              4446 non-null object
# lon              4446 non-null object
# category         4446 non-null object
# dtypes: int64(1), object(5)
# memory usage: 243.1+ KB

# %%
#형변환
main_place['lat']=main_place['lat'].astype(float)
main_place['lon']=main_place['lon'].astype(float)

# %%
main_place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4446 entries, 0 to 4855
# Data columns (total 6 columns):
# place_id         4446 non-null int64
# place_name       4446 non-null object
# place_address    4446 non-null object
# lat              4446 non-null float64
# lon              4446 non-null float64
# category         4446 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 243.1+ KB

# %%
main_place.columns
# Out:
# Index(['place_id', 'place_name', 'place_address', 'lat', 'lon', 'category'], dtype='object')

# %%
yjs = main_place

# %%
yjs.head(10)
# Out:
#    place_id        place_name                           place_address  \
# 0     10000     A아트홀(구.신연아트홀)                      서울특별시 종로구 동숭동 1-37
# 1     10001            BBC씨어터                    서울특별시 강남구 신사동  568-2
# 2     10002    BREAK OUT 전용극장                      서울특별시 종로구 관철동 33-1
# 3     10003         BYRDS(버즈)                       서울특별시 마포구 와우산로 51
# 4     10004  Between the Bars                     서울특별시 마포구 어울마당로 114
# 5     10005            CGV 강남         서울특별시 강남구 역삼동 814-6 스타플렉스 4-11층
# 6     10006            CGV 명동              서울특별시 중구 명동2가 83-5 눈스퀘어 8층
# 7     10007            CGV 상암                      서울특별시 마포구 월드컵로 240
# 8     10008            CGV 송파  서울특별시 송파구 문정동 294 가든파이브 라이프 YOUNG관 10층
# 9     10009             CGV강변                        서울특별시 강동구 성내로 48
#
#          lat         lon           category
# 0  37.583269  127.002443  movie/concerthall
# 1  37.523930  127.025143  movie/concerthall
# 2  37.568835  126.988123  movie/concerthall
# ...

# %%
yjs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4446 entries, 0 to 4855
# Data columns (total 6 columns):
# place_id         4446 non-null int64
# place_name       4446 non-null object
# place_address    4446 non-null object
# lat              4446 non-null float64
# lon              4446 non-null float64
# category         4446 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 243.1+ KB

# %%
hjs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9548 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         9548 non-null int64
# place_name       9548 non-null object
# place_address    9548 non-null object
# lat              9548 non-null float64
# lon              9548 non-null float64
# category         9548 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 522.2+ KB

# %% [markdown]
# # 합치자ㅡ

# %%
zzang = yjs.append(hjs)

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13994 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         13994 non-null int64
# place_name       13994 non-null object
# place_address    13994 non-null object
# lat              13994 non-null float64
# lon              13994 non-null float64
# category         13994 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 765.3+ KB

# %%
zzang.head()
# Out:
#    place_id        place_name         place_address        lat         lon  \
# 0     10000     A아트홀(구.신연아트홀)    서울특별시 종로구 동숭동 1-37  37.583269  127.002443
# 1     10001            BBC씨어터  서울특별시 강남구 신사동  568-2  37.523930  127.025143
# 2     10002    BREAK OUT 전용극장    서울특별시 종로구 관철동 33-1  37.568835  126.988123
# 3     10003         BYRDS(버즈)     서울특별시 마포구 와우산로 51  37.549100  126.922860
# 4     10004  Between the Bars   서울특별시 마포구 어울마당로 114  37.554833  126.923213
#
#             category
# 0  movie/concerthall
# 1  movie/concerthall
# 2  movie/concerthall
# 3  movie/concerthall
# 4  movie/concerthall

# %% [markdown]
# ----------------------

# %% [markdown]
# # 중복제거 로직 만들기

# %%
zzang[zzang.duplicated(subset=['lat','lon'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [place_id, place_name, place_address, lat, lon, category]
# Index: []

# %%
zzang[zzang.duplicated(subset=['place_address'],keep=False)].sort_values('place_address').count()
# Out:
# place_id         6002
# place_name       6002
# place_address    6002
# lat              6002
# lon              6002
# category         6002
# dtype: int64

# %%
zzang[zzang.duplicated(subset=['place_name'],keep=False)].sort_values('place_name').count()  ##<< 당첨
# Out:
# place_id         8204
# place_name       8204
# place_address    8204
# lat              8204
# lon              8204
# category         8204
# dtype: int64

# %%
zzang[zzang.duplicated(subset=['place_name','place_address'],keep=False)].sort_values('place_name').count()
# Out:
# place_id         5296
# place_name       5296
# place_address    5296
# lat              5296
# lon              5296
# category         5296
# dtype: int64

# %%
zzang.drop_duplicates(subset=['place_name'],inplace=True)

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9586 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         9586 non-null int64
# place_name       9586 non-null object
# place_address    9586 non-null object
# lat              9586 non-null float64
# lon              9586 non-null float64
# category         9586 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 524.2+ KB

# %%
zzang[zzang.place_name == '-'] # 이거 빼야함.
# Out:
#     place_id place_name         place_address        lat         lon category
# 20       966          -  서울특별시 금천구 독산로58가길 56  37.464426  126.906836   UC0H01

# %%
zzang[zzang.place_id == 966]
# Out:
#     place_id place_name         place_address        lat         lon category
# 20       966          -  서울특별시 금천구 독산로58가길 56  37.464426  126.906836   UC0H01

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9586 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         9586 non-null int64
# place_name       9586 non-null object
# place_address    9586 non-null object
# lat              9586 non-null float64
# lon              9586 non-null float64
# category         9586 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 524.2+ KB

# %%
zzang = zzang[zzang.place_address != '서울특별시 금천구 독산로58가길 56']

# %%
zzang.info() # 이름이 '-'인거 하나 뺌
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9585 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         9585 non-null int64
# place_name       9585 non-null object
# place_address    9585 non-null object
# lat              9585 non-null float64
# lon              9585 non-null float64
# category         9585 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 524.2+ KB

# %%
zzang[zzang.place_name == '-'] # 빠짐.
# Out:
# Empty DataFrame
# Columns: [place_id, place_name, place_address, lat, lon, category]
# Index: []

# %%
zzang.head()
# Out:
#    place_id        place_name         place_address        lat         lon  \
# 0     10000     A아트홀(구.신연아트홀)    서울특별시 종로구 동숭동 1-37  37.583269  127.002443
# 1     10001            BBC씨어터  서울특별시 강남구 신사동  568-2  37.523930  127.025143
# 2     10002    BREAK OUT 전용극장    서울특별시 종로구 관철동 33-1  37.568835  126.988123
# 3     10003         BYRDS(버즈)     서울특별시 마포구 와우산로 51  37.549100  126.922860
# 4     10004  Between the Bars   서울특별시 마포구 어울마당로 114  37.554833  126.923213
#
#             category
# 0  movie/concerthall
# 1  movie/concerthall
# 2  movie/concerthall
# 3  movie/concerthall
# 4  movie/concerthall

# %%
zzang[zzang.place_name.isnull()]
# Out:
# Empty DataFrame
# Columns: [place_id, place_name, place_address, lat, lon, category]
# Index: []

# %% [markdown]
# # toilets

# %%
jms_toilet = pd.read_csv('seoul_toilets.csv',usecols={'place_id','place_name','place_address','lat','lon','category'})

# %%
jms_toilet = jms_toilet[['place_id','place_name','place_address','lat','lon','category']]

# %%
jms_toilet.head()
# Out:
#    place_id place_name         place_address        lat         lon  \
# 0    300000  남대문시장 화장실     서울특별시 중구 남창동 51-2  37.559433  126.976225
# 1    300001    광희동 화장실  서울특별시 중구 광희동1가 202-1  37.564371  127.006306
# 2    300002  신당 1호 화장실  서울특별시 중구 신당동 236-542  37.563819  127.013347
# 3    300003  신당 2호 화장실   서울특별시 중구 신당동 298-74  37.561325  127.013778
# 4    300004    청구역 화장실   서울특별시 중구 신당동 297-17  37.561317  127.013783
#
#       category
# 0  toilet/open
# 1  toilet/open
# 2  toilet/open
# 3  toilet/open
# 4  toilet/open

# %%
# name, lat 으로 중복하면안됨. name 은 이미 toilets 에 중복이있음( 대신 lat,lon 이 다름)

# %%
jms_toilet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 6 columns):
# place_id         1117 non-null int64
# place_name       1117 non-null object
# place_address    1117 non-null object
# lat              1117 non-null float64
# lon              1117 non-null float64
# category         1117 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 52.4+ KB

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9585 entries, 0 to 10430
# Data columns (total 6 columns):
# place_id         9585 non-null int64
# place_name       9585 non-null object
# place_address    9585 non-null object
# lat              9585 non-null float64
# lon              9585 non-null float64
# category         9585 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 524.2+ KB

# %%
zzang = zzang.append(jms_toilet)

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10702 entries, 0 to 1116
# Data columns (total 6 columns):
# place_id         10702 non-null int64
# place_name       10702 non-null object
# place_address    10702 non-null object
# lat              10702 non-null float64
# lon              10702 non-null float64
# category         10702 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 585.3+ KB

# %% [markdown]
# # Facilities

# %%
jms_facility = pd.read_csv('facility_cleansed.csv')

# %%
jms_facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 7 columns):
# Unnamed: 0       323 non-null int64
# category         323 non-null object
# place_name       323 non-null object
# place_address    323 non-null object
# lat              323 non-null float64
# lon              323 non-null float64
# place_id         323 non-null int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 17.7+ KB

# %%
jms_facility=jms_facility[['place_id','place_name','place_address','lat','lon','category']]

# %%
jms_facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 6 columns):
# place_id         323 non-null int64
# place_name       323 non-null object
# place_address    323 non-null object
# lat              323 non-null float64
# lon              323 non-null float64
# category         323 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 15.2+ KB

# %%
jms_facility.head()
# Out:
#    place_id place_name                        place_address        lat  \
# 0     40000         영락                  중구 수표로 33 (저동2가 69)  37.563202
# 1     40001   역삼주간보호센터  강남구 테헤란로8길 36 (역삼동 827-61) 강남문화원 2층  37.496507
# 2     40002   성민장애인복지관          노원구 노원로32길 30-3 (상계동 321-9)  37.655624
# 3     40003  강서뇌성마비복지관           강서구 방화대로45길 69 (방화동 452-5)  37.574198
# 4     40004      모랫말꿈터            영등포구 도영로 37 (도림2동 205-24)  37.510186
#
#           lon  category
# 0  126.989182   daycare
# 1  127.032048   daycare
# 2  127.069340  wellfare
# 3  126.812585  wellfare
# 4  126.897488   daycare

# %%
jms_facility[jms_facility.duplicated(subset=['lat','lon'],keep=False)].sort_values('lat')
# Out:
#      place_id           place_name  \
# 306     40314             성분도보호작업장
# 64      40066               성분도복지관
# 10      40011             SRC재활체육관
# 123     40126              SRC재활병원
# 97      40099            다니엘주간보호센터
# 270     40278          다니엘직업재활원(♠)
# 8       40009           성모자애제1주간보호
# 128     40131           성모자애제2주간보호
# 111     40114              성모자애복지관
# 275     40283           성모자애 보호작업장
# 314     40322          갑을장애인주간보호센터
# 269     40277         갑을장애인 직업휴먼센터
# 177     40182                  햇살터
# 244     40252       성프란치스코장애인종합복지관
# 252     40260                해나무일터
# 115     40118                  서리풀
# 274     40282             한우리보호작업장
# 13      40014               마라주간보호
# 291     40299              마라보호작업장
# 279     40287               밀알베이커리
# 278     40286             우리플러스작업장
# 100     40102                  한우리
# 281     40289              밀알보호작업장
# 138     40142             하상장애인복지관
# 7       40008                   하상
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
zzang = zzang.append(jms_facility) # 나중에 에러가 될수있으니 유의!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
zzang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11025 entries, 0 to 322
# Data columns (total 6 columns):
# place_id         11025 non-null int64
# place_name       11025 non-null object
# place_address    11025 non-null object
# lat              11025 non-null float64
# lon              11025 non-null float64
# category         11025 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 602.9+ KB

# %%
pd.DataFrame.to_csv(zzang,'yj_hj_jm.csv')

# %%
zzang[zzang.duplicated(subset=['place_address'],keep=False)].sort_values('place_address')
# Out:
#        place_id            place_name               place_address        lat  \
# 138       40142              하상장애인복지관      강남구 개포로 613 (개포동 12-5)  37.492533
# 7         40008                    하상      강남구 개포로 613 (개포동 12-5)  37.492533
# 128       40131            성모자애제2주간보호  강남구 헌릉로757길 35 (율현동 110번지)  37.470543
# 8         40009            성모자애제1주간보호  강남구 헌릉로757길 35 (율현동 110번지)  37.470543
# 201       40207            기쁜우리재활체육센터       강서구 허준로 65 (가양동 1466)  37.569363
# 48        40050                  기쁜우리       강서구 허준로 65 (가양동 1466)  37.569363
# 1872      11872               개포 고등학교           서울특별시 강남구 개포로 402  37.485056
# 768        2017                개포고등학교           서울특별시 강남구 개포로 402  37.484959
# 341        1398                  SH공사           서울특별시 강남구 개포로 621  37.494130
# 920       10920              LH서울지역본부           서울특별시 강남구 개포로 621  37.494133
# 2251       5149                  대진공원        서울특별시 강남구 개포로109길 62  37.496055
# ...

# %%
zzang.tail()
# Out:
#      place_id  place_name                              place_address  \
# 318     40326        로뎀나무            강서구 까치산로18나길 36 (화곡동 772-60 1층)
# 319     40327         양지골             구로구 구로중앙로28길 62 5층 (구로동 109-3)
# 320     40328  파란마음주간보호센터              중구 다산로22길 11 (신당동 340-180) 1층
# 321     40329   송파구수화통역센터  서울시 송파구 송파1동 15-2 3층 서울시 송파구 송파대로 460, 3층
# 322     40330        TEST                     서울특별시 강남구 학동로 402 TEST
#
#            lat         lon       category
# 318  37.545872  126.849567        daycare
# 319  37.499968  126.889072        daycare
# 320  37.557676  127.013070        daycare
# 321  37.507644  127.105472  signinterpret
# 322  37.516988  127.041807  education/job

# %%
jms_facility[jms_facility.duplicated(subset=['lat','lon'],)].count() # lat , lon 의 중복제거
# Out:
# place_id         63
# place_name       63
# place_address    63
# lat              63
# lon              63
# category         63
# dtype: int64

# %%
jms_toilet[jms_toilet.duplicated(subset=['lat','lon'],)].count() # lat , lon 의 중복제거
# Out:
# place_id         0
# place_name       0
# place_address    0
# lat              0
# lon              0
# category         0
# dtype: int64

# %%
hjs[hjs.duplicated(subset=['lat','lon'],)].count() # lat , lon 의 중복제거
# Out:
# place_id         0
# place_name       0
# place_address    0
# lat              0
# lon              0
# category         0
# dtype: int64

# %%
yjs[yjs.duplicated(subset=['lat','lon'],)].count() # lat , lon 의 중복제거
# Out:
# place_id         0
# place_name       0
# place_address    0
# lat              0
# lon              0
# category         0
# dtype: int64

# %%
zzang[zzang.duplicated(subset=['lat','lon'],)].count() # lat , lon 의 중복제거
# Out:
# place_id         71
# place_name       71
# place_address    71
# lat              71
# lon              71
# category         71
# dtype: int64

# %%
# 71 개의 데이터가 전체 중 lat,lon 이 중복됨. 그중 63개는 jms_facility 에서 중복제거 안하고 들어온것들.

# %%
zzang.drop_duplicates(subset=['lat','lon'],inplace=True)

# %%
zzang.info() # lat , lon 을 통해 중복을 제거한 테이블구성.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10954 entries, 0 to 322
# Data columns (total 6 columns):
# place_id         10954 non-null int64
# place_name       10954 non-null object
# place_address    10954 non-null object
# lat              10954 non-null float64
# lon              10954 non-null float64
# category         10954 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 599.0+ KB

# %% [markdown]
# # 중복제거에 더많은 시간이 필요하다고 판단되어 다른 로직 탐색중
